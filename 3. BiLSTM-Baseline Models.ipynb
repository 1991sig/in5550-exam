# %%
# !pip install torchtext --upgrade
# Out:
# Collecting torchtext
#   Downloading https://files.pythonhosted.org/packages/f2/17/e7c588245aece7aa93f360894179374830daf60d7ed0bbb59332de3b3b61/torchtext-0.6.0-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 2.5MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/98/2c/8df20f3ac6c22ac224fff307ebc102818206c53fc454ecd37d8ac2060df5/sentencepiece-0.1.86-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 10.3MB/s
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.12.0)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext) (4.38.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.18.3)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied, skipping upgrade: torch in /usr/local/lib/python3.6/dist-packages (from torchtext) (1.5.0+cu101)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2.9)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch->torchtext) (0.16.0)
# Installing collected packages: sentencepiece, torchtext
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# Successfully installed sentencepiece-0.1.86 torchtext-0.6.0

# %%
# %cd /content/drive/"My Drive"/in5550-exam
# Out:
# /content/drive/My Drive/in5550-exam

# %%
import argparse
import random
import torch
import torchtext
from torchtext import data
import NSR

# %%
import pickle
import os

# %%
args = argparse.Namespace(setupfile="Setup.json")
setup = NSR.Process(args)

# %%
RSEED = setup["randomseed"]
random.seed(RSEED)
torch.manual_seed(RSEED)
torch.backends.cudnn.deterministic = True

ID = data.RawField(preprocessing=lambda x: int(x))
SRC = data.RawField()
NEGS = data.RawField(preprocessing=lambda x: int(x))
FORM = data.Field(batch_first=True, include_lengths=True)
LEMMA = data.RawField()
XPOS = data.RawField()
LABS = data.Field(batch_first=True, unk_token=None)
CUE = data.Field(batch_first=True)
SCOPE = data.RawField()

fields = {
    "id": ("id", ID),
    "source": ("source", SRC),
    "negations": ("negations", NEGS),
    "form": ("form", FORM),
    "lemma": ("lemma", LEMMA),
    "xpos": ("xpos", XPOS),
    "negation": ("label", LABS),
    "cue": ("cue", CUE),
    "scope": ("scope", SCOPE),
}

Xtrain, Xdev = NSR.StarSEM2012.splits(
    "DataFiles",
    fields=fields,
    test=None
)


if setup["params"]["vectors"]:
  vecs = torchtext.vocab.Vectors(setup["params"]["vectors"])
else:
  vecs = None

FORM.build_vocab(Xtrain,
                  max_size=setup["params"]["vocab_size"],
                  min_freq=setup["params"]["min_freq"],
                  vectors=vecs)

CUE.build_vocab(Xtrain, vectors=vecs)

LABS.build_vocab(Xtrain)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vecs = FORM.vocab.vectors

model = setup.load("model", NSR.Models,
                    input_dim=len(FORM.vocab),
                    output_dim=len(LABS.vocab)
                    ).to(device)

optimizer = setup.load("optimizer", torch.optim, model.parameters())

criterion = setup.load("criterion", torch.nn, weight=None).to(device)

runner = setup.load("runner", NSR.Runners, model,
                    criterion, optimizer, LABS.vocab.itos)

batch_size = setup["params"]["batchsize"]
epochs = setup["params"]["epochs"]

trn_iter = data.BucketIterator(
    Xtrain,
    device=device,
    shuffle=True,
    batch_size=batch_size
)

val_iter = data.BucketIterator(
    Xdev,
    device=device,
    shuffle=True,
    batch_size=1
)

# %%
print(model)
# Out:
# BiLSTMC(
#   (w_embedding): Embedding(5779, 50)
#   (c_embedding): Embedding(5779, 50)
#   (lstm): LSTM(50, 250, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=500, out_features=5, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %% [markdown]
# # 2. Training

# %%
runner.run(epochs, trn_iter, val_iter)
# Out:
# 100%|██████████| 315/315 [00:05<00:00, 59.03it/s]
# 100%|██████████| 816/816 [00:02<00:00, 341.68it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
#   2%|▏         | 6/315 [00:00<00:05, 56.83it/s]
# {'accuracy': 0.8939181614349776, 'precision': 0.1787836322869955, 'recall': 0.2, 'macro_f1': 0.18879763226045135, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12758, 0, 0, 0], [0, 1335, 0, 0, 0], [0, 146, 0, 0, 0], [0, 33, 0, 0, 0]]}
# 100%|██████████| 315/315 [00:05<00:00, 60.47it/s]
# 100%|██████████| 816/816 [00:02<00:00, 337.83it/s]
#   2%|▏         | 5/315 [00:00<00:06, 49.27it/s]
# {'accuracy': 0.9023963004484304, 'precision': 0.4230412213452345, 'recall': 0.35355292186137194, 'macro_f1': 0.3591004872190463, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12758, 0, 0, 0], [0, 1325, 10, 0, 0], [0, 22, 13, 111, 0], [0, 12, 11, 10, 0]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.30it/s]
# 100%|██████████| 816/816 [00:02<00:00, 334.48it/s]
#   2%|▏         | 7/315 [00:00<00:05, 59.99it/s]
# {'accuracy': 0.9185117713004485, 'precision': 0.5356270348191037, 'recall': 0.43232124603612154, 'macro_f1': 0.426157800053485, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12746, 12, 0, 0], [0, 1117, 217, 1, 0], [0, 0, 0, 146, 0], [0, 0, 0, 33, 0]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.43it/s]
# 100%|██████████| 816/816 [00:02<00:00, 329.66it/s]
#   2%|▏         | 6/315 [00:00<00:05, 55.39it/s]
# {'accuracy': 0.9366591928251121, 'precision': 0.5488878512722082, 'recall': 0.4648498856165313, 'macro_f1': 0.4866675358854712, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12720, 38, 0, 0], [0, 825, 510, 0, 0], [0, 0, 8, 138, 0], [0, 1, 20, 12, 0]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.88it/s]
# 100%|██████████| 816/816 [00:02<00:00, 337.97it/s]
#   2%|▏         | 7/315 [00:00<00:04, 62.25it/s]
# {'accuracy': 0.9573290358744395, 'precision': 0.7440276446768261, 'recall': 0.675666471142763, 'macro_f1': 0.7037457045643866, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12669, 89, 0, 0], [0, 510, 825, 0, 0], [0, 0, 0, 143, 3], [0, 1, 0, 6, 26]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.61it/s]
# 100%|██████████| 816/816 [00:02<00:00, 339.47it/s]
#   2%|▏         | 6/315 [00:00<00:05, 54.62it/s]
# {'accuracy': 0.9558576233183856, 'precision': 0.7691019124476067, 'recall': 0.6647701731128214, 'macro_f1': 0.7042811728547187, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12710, 48, 0, 0], [0, 573, 761, 1, 0], [0, 0, 0, 146, 0], [0, 1, 0, 7, 25]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.86it/s]
# 100%|██████████| 816/816 [00:02<00:00, 337.59it/s]
#   2%|▏         | 6/315 [00:00<00:05, 55.77it/s]
# {'accuracy': 0.9632146860986547, 'precision': 0.7512780330217657, 'recall': 0.7153774304967639, 'macro_f1': 0.7292877949957747, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12678, 80, 0, 0], [0, 438, 896, 1, 0], [0, 0, 0, 142, 4], [0, 1, 0, 1, 31]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.82it/s]
# 100%|██████████| 816/816 [00:02<00:00, 332.82it/s]
#   2%|▏         | 6/315 [00:00<00:05, 51.53it/s]
# {'accuracy': 0.9658772421524664, 'precision': 0.7669415454685165, 'recall': 0.7353360289091887, 'macro_f1': 0.749314942246823, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12643, 115, 0, 0], [0, 370, 965, 0, 0], [0, 0, 0, 145, 1], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.57it/s]
# 100%|██████████| 816/816 [00:02<00:00, 335.14it/s]
#   2%|▏         | 6/315 [00:00<00:05, 56.45it/s]
# {'accuracy': 0.961042600896861, 'precision': 0.7772598116116853, 'recall': 0.7146704554832762, 'macro_f1': 0.7384346115274878, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12720, 38, 0, 0], [0, 516, 819, 0, 0], [0, 0, 0, 145, 1], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.74it/s]
# 100%|██████████| 816/816 [00:02<00:00, 335.00it/s]
#   2%|▏         | 6/315 [00:00<00:05, 55.90it/s]
# {'accuracy': 0.9677690582959642, 'precision': 0.7765730442902312, 'recall': 0.737918297093646, 'macro_f1': 0.7551211802819213, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12663, 95, 0, 0], [0, 364, 971, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.80it/s]
# 100%|██████████| 816/816 [00:02<00:00, 330.54it/s]
#   2%|▏         | 6/315 [00:00<00:05, 57.09it/s]
# {'accuracy': 0.968539798206278, 'precision': 0.7795066930631513, 'recall': 0.737151783844707, 'macro_f1': 0.7557335024105006, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12681, 77, 0, 0], [0, 371, 964, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.93it/s]
# 100%|██████████| 816/816 [00:02<00:00, 335.83it/s]
#   2%|▏         | 6/315 [00:00<00:05, 56.50it/s]
# {'accuracy': 0.9648262331838565, 'precision': 0.7827798198410132, 'recall': 0.7253217563610337, 'macro_f1': 0.748811508391706, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12710, 48, 0, 0], [0, 453, 882, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.43it/s]
# 100%|██████████| 816/816 [00:02<00:00, 340.40it/s]
#   2%|▏         | 6/315 [00:00<00:05, 52.97it/s]
# {'accuracy': 0.967979260089686, 'precision': 0.7782363651976335, 'recall': 0.7368922360424321, 'macro_f1': 0.7550939740360395, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12674, 84, 0, 0], [0, 372, 963, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.48it/s]
# 100%|██████████| 816/816 [00:02<00:00, 337.45it/s]
#   2%|▏         | 6/315 [00:00<00:05, 56.00it/s]
# {'accuracy': 0.9676289237668162, 'precision': 0.7836229233348575, 'recall': 0.7314484020200989, 'macro_f1': 0.7533874294179033, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12709, 49, 0, 0], [0, 412, 923, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 59.43it/s]
# 100%|██████████| 816/816 [00:02<00:00, 335.38it/s]
#   2%|▏         | 6/315 [00:00<00:05, 57.85it/s]
# {'accuracy': 0.968329596412556, 'precision': 0.7738253969461558, 'recall': 0.7362999367551524, 'macro_f1': 0.7523385338489522, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12684, 74, 0, 0], [0, 376, 958, 0, 1], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# 100%|██████████| 315/315 [00:05<00:00, 58.97it/s]
# 100%|██████████| 816/816 [00:02<00:00, 330.02it/s]
# {'accuracy': 0.9626541479820628, 'precision': 0.780877961030376, 'recall': 0.7214823793790945, 'macro_f1': 0.745440644169225, 'confusion_matrix': [[0, 0, 0, 0, 0], [0, 12704, 54, 0, 0], [0, 478, 857, 0, 0], [0, 0, 0, 146, 0], [0, 1, 0, 0, 32]]}
# Stopping after no improvement for 5 epochs

# %% [markdown]
# # 3. Dev/Validation Set Results

# %%
dev_res = runner.evaluate(val_iter)
# Out:
# 100%|██████████| 816/816 [00:02<00:00, 330.63it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)

# %%
print("*"*21)
print("{} {}".format(setup["identifier"], setup["ID"]))
print("Results:")
for i in ["accuracy", "precision", "recall", "macro_f1"]:
  print("\t{}: {:2f}".format(i, dev_res[i]))
print("Confusion Matrix: \n")
for i in dev_res["confusion_matrix"]:
  print(i)
# Out:
# *********************
# BiLSTM-C Baseline_incr_hidd
# Results:
# 	accuracy: 0.962654
# 	precision: 0.780878
# 	recall: 0.721482
# 	macro_f1: 0.745441
# Confusion Matrix:
#
# [0, 0, 0, 0, 0]
# [0, 12704, 54, 0, 0]
# [0, 478, 857, 0, 0]
# [0, 0, 0, 146, 0]
# [0, 1, 0, 0, 32]

# %% [markdown]
# # 4. Save

# %%
with open(os.path.join(setup.destdir, "form"), "wb") as o:
  pickle.dump(FORM.vocab, o)

with open(os.path.join(setup.destdir, "cue"), "wb") as o:
  pickle.dump(CUE.vocab, o)

with open(os.path.join(setup.destdir, "labels"), "wb") as o:
  pickle.dump(LABS.vocab, o)

# %%
runner.save(dirpath=setup.destdir, checkpoint=True)

# %% [markdown]
# # Evaluator

# %%
import glob
import argparse
import random
import torch
import torchtext
from torchtext import data
import NSR
import pickle
import os
import json
from collections import OrderedDict, defaultdict
from pathlib import Path


class LabelMapper():
  
  def __init__(self, vocab_stoi, vocab_itos):
    self.label2ind = vocab_stoi
    self.labelset = vocab_itos
    
  def index2label(self, x):
    return self.labelset[x]
  
  def label2index(self, x):
    return self.label2ind[x]
        
  def __call__(self, x):
    if type(x) == int:
      self.index2label(x)
    elif type(x) == str:
      self.label2index(x)
    else:
      raise ValueError("This is not a valid key")


class Evaluator():
  """Use a saved model to evaluate on held out dataset.

  Loads a saved model and vocabularies to be used for
  predicting new data.
  """

  def __init__(self, saved_model_dir=None):
    self.work_dir = saved_model_dir
    
    setup_file = os.path.join(self.work_dir, "setup.json")
    with open(setup_file, "rt") as f:
        self.setup = json.load(f, object_hook=OrderedDict)
    
    with open(os.path.join(self.work_dir, "form"), "rb") as f:
      self.form_voc = pickle.load(f)
    
    with open(os.path.join(self.work_dir, "cue"), "rb") as f:
      self.cue_voc = pickle.load(f)
    
    with open(os.path.join(self.work_dir, "labels"), "rb") as f:
      self.lab_voc = pickle.load(f)
    
    modelfile = glob.glob(os.path.join(self.work_dir, "model_epoch*.pt"))[0]
    state_dict = torch.load(modelfile)["model_state_dict"]
    self.device = state_dict["fc.bias"].device
    
    model = self._load("model", NSR.Models, input_dim=len(self.form_voc),
                       output_dim=len(self.lab_voc)).to(self.device)
    
    model.load_state_dict(state_dict)
    self.model = model
    self.model.eval()

    self.FORM = data.Field(batch_first=True, include_lengths=True)
    self.LABS = data.Field(batch_first=True, unk_token=None)
    self.CUE = data.Field(batch_first=True)

    self.FORM.vocab = self.form_voc
    self.CUE.vocab = self.cue_voc
    self.LABS.vocab = self.lab_voc

    # Since the vocabs are not pickled as defaultdicts:
    self.FORM.vocab.stoi = defaultdict(torchtext.vocab._default_unk_index,
                                       self.FORM.vocab.stoi)
    self.CUE.vocab.stoi = defaultdict(torchtext.vocab._default_unk_index,
                                       self.CUE.vocab.stoi)

    self.mapp = LabelMapper(self.LABS.vocab.stoi,
                            self.LABS.vocab.itos)
    
    self.correction_log = []


  def map_node(self, id, f, l, x):
    return {"id": str(id), 
            "form": f, 
            "properties": {"lemma": l, "xpos": x}}
  
  def map_back_gold(self, sentence):
    out = sentence.copy()
  
    form = out.pop("form")
    lemma = out.pop("lemma")
    xpos = out.pop("xpos")
    cue = out.pop("cue")
    scope = out.pop("scope")
    negation = out.pop("negation")

    nodes = []

    if out["negations"] == 0:
      for i in range(len(form)):
        nodes.append(self.map_node(i, form[i], lemma[i], xpos[i]))
  
    else:
      for i in range(len(form)):
        node = self.map_node(i, form[i], lemma[i], xpos[i])
        if negation[i] == "T":
          node["negation"] = [{"id": 0}]
        elif negation[i] == "F":
          node["negation"] = [{"id": 0, "scope": scope[i]}]
        elif negation[i] == "C":
          node["negation"] = [{"id": 0, "cue": cue[i]}]
        elif negation[i] == "A":
          node["negation"] = [{"id": 0, "cue": cue[i], "scope": scope[i]}]
        else:
          node["negation"] = [{"id": 0}]

        nodes.append(node)

    out["nodes"] = nodes
    return out
  
  def map_back_pred(self, sentence):
    out = sentence.copy()
  
    form = out.pop("form")
    lemma = out.pop("lemma")
    xpos = out.pop("xpos")
    cue = out.pop("cue")
    scope = out.pop("scope")
    negation = out.pop("negation")

    nodes = []

    # To handle logic in the 'convert.py' file
    # need to set negations to 0

    if set(negation).issubset(set("T")):
      out["negations"] = 0
    else:
      out["negations"] = 1

    if out["negations"] == 0:
      for i in range(len(form)):
        nodes.append(self.map_node(i, form[i], lemma[i], xpos[i]))
  
    else:
      for i in range(len(form)):
        node = self.map_node(i, form[i], lemma[i], xpos[i])
        if negation[i] == "T":
          node["negation"] = [{"id": 0}]
        elif negation[i] == "F":
          node["negation"] = [{"id": 0, "scope": scope[i]}]
        elif negation[i] == "C":
          node["negation"] = [{"id": 0, "cue": cue[i]}]
        elif negation[i] == "A":
          node["negation"] = [{"id": 0, "cue": cue[i], "scope": scope[i]}]
        else:
          node["negation"] = [{"id": 0}]

        nodes.append(node)

    out["nodes"] = nodes
    return out  

  
  def _correct_preds(self, pred_labs, id, src):
    """Apply a simple constraint on the predictions."""

    n_cues = pred_labs.count("A") + pred_labs.count("C")

    # No predicted cues, but has scope
    if n_cues == 0 and not set(pred_labs).issubset(set("T")):
      # Correct everything to true
      out_labs = ["T"]*len(pred_labs)
      self.correction_log.append({"id": id, "source": src})
      return out_labs
    
    return pred_labs

  
  def pred(self, batch, apply_dk=False):
    with torch.no_grad():
      form_b = self.FORM.process([batch["form"]], device=self.device)
      cue_b = self.CUE.process([batch["cue"]], device=self.device)
      lab_b = self.LABS.process([batch["negation"]], device=self.device)

      y_tilde = self.model(form_b, cue_b)
      y_hat = y_tilde.argmax(dim=-1).cpu().flatten().tolist()
      y_hat = [self.mapp.index2label(l) for l in y_hat]
      if apply_dk:
        y_hat = self._correct_preds(y_hat, batch["id"], batch["source"])

      y_b = batch["negation"]
      return y_b, y_hat
  
  def output_preds(self, eval_file, results_file=None, apply_dk=False):
    if not results_file:
      results_file = "eval_pred.epe"

    out_file = os.path.join(self.work_dir, results_file)

    if os.path.isfile(out_file):
      raise Exception("There is already a file there")
    
    with open(eval_file) as f, open(out_file, "wt") as r:
      for line in f:
        sent = json.loads(line)
        _, y_pred = self.pred(sent, apply_dk)
        sent["negation"] = y_pred
        sent = self.map_back_pred(sent)
        json.dump(sent, r)
        r.write("\n")
    
    n_corr = len(self.correction_log)
    if apply_dk and n_corr > 0:
      with open(os.path.join(self.work_dir, "correction_log.txt"), "w") as log:
        for corr in self.correction_log:
          json.dump(corr, log)
          log.write("\n")

      print("{} corrections applied, see correction_log.txt".format(n_corr))
    
    print("File saved to {}".format(out_file))

  def output_preds_tidy(self, eval_file, results_file=None, apply_dk=False):
    if not results_file:
      results_file = "eval_pred_tidy.epe"

    out_file = os.path.join(self.work_dir, results_file)

    if os.path.isfile(out_file):
      raise Exception("There is already a file there")
    
    with open(eval_file) as f, open(out_file, "wt") as r:
      for line in f:
        sent = json.loads(line)
        _, y_pred = self.pred(sent, apply_dk)
        sent["negation"] = y_pred
        json.dump(sent, r)
        r.write("\n")
    
    print("File saved to {}".format(out_file))


  def _load(self, argname, module, *args, **kwargs):
    item = self.setup[argname]["type"]
    item_args = dict(self.setup[argname]["args"])
    if sum([kwarg in item_args for kwarg in kwargs]) != 0:
      raise ValueError("Args set in config file cannot be overwritten")
    item_args.update(kwargs)
    
    return getattr(module, item)(*args, **item_args)

# %% [markdown]
# Run evaluation

# %%
ev = Evaluator("Saves/BiLSTM-C/Baseline_incr_hidd")

# %%
ev.output_preds(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred_final.epe",
                apply_dk=False)
# Out:
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_final.epe

# %%
ev.output_preds(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred_corr_final.epe",
                apply_dk=True)
# Out:
# 1 corrections applied, see correction_log.txt
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_corr_final.epe

# %%
ev.output_preds_tidy(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred_corr_tidy.epe",
                apply_dk=True)
# Out:
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_corr_tidy.epe

# %%
ev.output_preds_tidy(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred_tidy.epe",
                apply_dk=False)
# Out:
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_tidy.epe

# %% [markdown]
# # Using `score.py` to evaluate:

# %%
import sys
sys.path.append("negation")

# %%
from negation import score, convert

# %%
# %cd ..
# Out:
# /content/drive/My Drive/in5550-exam

# %% [markdown]
# Read the gold labels and predictions

# %%
s_gold = convert.read_negations("EvalFiles/eval_gold.epe")

# %%
s_pred = convert.read_negations("Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_corr_final.epe")

# %%
file = "Baseline_incr_hidd_corr_score_final.txt"

# %%
# %cd negation
# Out:
# /content/drive/My Drive/in5550-exam/negation

# %%
score.starsem_score(s_gold, s_pred, file)

# %%
os.chdir("")

# %% [markdown]
# ***********************************************
#
# # Testing

# %%
runner.labelvals
# Out:
# ['<pad>', 'T', 'F', 'C', 'A']

# %%
res
# Out:
# {'accuracy': 0.09353979820627803,
#  'confusion_matrix': [[0, 0, 0, 0, 0],
#   [0, 0, 12758, 0, 0],
#   [0, 0, 1335, 0, 0],
#   [0, 0, 146, 0, 0],
#   [0, 0, 33, 0, 0]],
#  'macro_f1': 0.03421541615941565,
#  'precision': 0.018707959641255607,
#  'recall': 0.2}

# %% [markdown]
# ### Dev

# %%
torch.load("Saves/BiLSTM-C/Baseline/checkpoint_stats")
# Out:
# {'eval': {'accuracy': 0.9513032511210763,
#   'confusion_matrix': [[0, 0, 0, 0, 0],
#    [0, 12542, 216, 0, 0],
#    [0, 476, 859, 0, 0],
#    [0, 0, 1, 144, 1],
#    [0, 1, 0, 0, 32]],
#   'macro_f1': 0.7296966771068604,
#   'precision': 0.7462770697012415,
#   'recall': 0.7165026958131212},
#  'train': {'loss': 0.2042346529958584}}

# %% [markdown]
# Save Baseline

# %% [markdown]
# Save Baseline_incr_hidd

# %%
ev = Evaluator("Saves/BiLSTM-C/Baseline_incr_hidd")

# %%
ev.output_preds(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred.epe",
                apply_dk=False)
# Out:
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred.epe

# %%
ev.output_preds(eval_file="DataFiles/cde.epe", 
                results_file="eval_pred_corr.epe",
                apply_dk=True)
# Out:
# 3 corrections applied, see correction_log.txt
# File saved to Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_corr.epe

# %%
import sys

# %%
sys.path.append("negation")

# %%
from negation import score

# %%
ev.FORM.vocab.stoi

# %%
inv_id = []
inv_src = []
for i in s:
  gold, pred = ev.pred(i)
  if "A" in gold or "C" in gold:
    print("Gold: {}".format(gold))
    print("Pred: {}".format(pred))
    print("*"*21)
  if pred.count("A") + pred.count("C") > 1 or gold.count("A") + gold.count("C") > 1:
    if gold.count("A") + gold.count("C") > 1:
      inv_id.append(i["id"])
      inv_src.append(i["source"])
    print("\t\n\n" + "#"*21)
    print(i["form"])
    print("id: ", i["id"], "\t", "source:", i["source"] )
    print("\t\tGold: {}".format(gold))
    print("\t\tPred: {}".format(pred))
# Out:
# Gold: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'T', 'A', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'A', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'A', 'F', 'T', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'T', 'T']
# *********************
# Gold: ['F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'C', 'F', 'F', 'T', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'C', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'F', 'C', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'C', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'C', 'F', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
#
#
# #####################
# ['The', 'dinner', 'itself', 'was', 'neither', 'well', 'served', 'nor', 'well', 'cooked', ',', 'and', 'the', 'gloomy', 'presence', 'of', 'the', 'taciturn', 'servant', 'did', 'not', 'help', 'to', 'enliven', 'us', '.']
# id:  122 	 source: wisteria01
# 		Gold: ['F', 'F', 'F', 'F', 'C', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# 		Pred: ['T', 'T', 'T', 'F', 'C', 'F', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'F', 'F', 'C', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'C', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'T']
# *********************
# Gold: ['C', 'F', 'T']
# Pred: ['C', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# Pred: ['F', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'C', 'F', 'T']
# Pred: ['T', 'F', 'T', 'F', 'C', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'A', 'F', 'T']
# Pred: ['F', 'F', 'F', 'A', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'A', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'C', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'A', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'F', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['F', 'T', 'C', 'F', 'C', 'F', 'T', 'F', 'F', 'T', 'T', 'T']
# *********************
#
#
# #####################
# ['There', 'are', 'no', 'footsteps', 'nor', 'any', 'clue', 'to', 'the', 'criminals', '.', "''"]
# id:  221 	 source: wisteria01
# 		Gold: ['F', 'F', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# 		Pred: ['F', 'T', 'C', 'F', 'C', 'F', 'T', 'F', 'F', 'T', 'T', 'T']
# Gold: ['T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'C', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'A', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
#
#
# #####################
# ['It', 'was', 'after', 'nine', 'this', 'morning', 'when', 'we', 'reached', 'his', 'house', 'and', 'found', 'neither', 'you', 'nor', 'anyone', 'else', 'inside', 'it', '.']
# id:  230 	 source: wisteria01
# 		Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# 		Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Gold: ['T', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'A', 'T']
# Pred: ['T', 'T', 'T', 'T', 'A', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'C', 'C', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'C', 'C', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
#
#
# #####################
# ['``', 'Remarkable', ',', 'but', 'by', 'no', 'means', 'impossible', ',', "''", 'said', 'Holmes', ',', 'smiling', '.']
# id:  248 	 source: wisteria01
# 		Gold: ['T', 'T', 'T', 'T', 'C', 'C', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# 		Pred: ['T', 'T', 'T', 'T', 'C', 'C', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'A', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'T']
# *********************
# Gold: ['F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'C', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'F', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'F', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'F', 'T', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'F', 'F', 'C', 'F', 'T', 'T']
# Pred: ['F', 'F', 'F', 'F', 'F', 'C', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'C', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'T']
# *********************
# Gold: ['C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'T', 'T', 'T', 'C', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'T', 'F', 'T', 'F', 'F', 'F', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'F', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'F', 'F', 'A', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'A', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'F', 'T', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'A', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'A', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'T', 'T', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'A', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'T', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'F', 'F', 'F', 'F', 'A', 'F', 'F', 'F', 'F', 'T', 'T', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'C', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'T', 'T', 'F', 'F', 'F', 'F', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'F', 'C', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'F', 'F', 'F', 'T', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'F', 'F', 'C', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# Pred: ['T', 'T', 'C', 'T', 'F', 'T', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'C', 'C', 'F', 'F', 'T']
# Pred: ['T', 'T', 'F', 'F', 'F', 'F', 'C', 'C', 'F', 'T', 'T']
# *********************
#
#
# #####################
# ['From', 'that', 'day', 'they', 'were', 'seen', 'no', 'more', 'in', 'England', '.']
# id:  414 	 source: wisteria02
# 		Gold: ['F', 'F', 'F', 'F', 'F', 'F', 'C', 'C', 'F', 'F', 'T']
# 		Pred: ['T', 'T', 'F', 'F', 'F', 'F', 'C', 'C', 'F', 'T', 'T']
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'F', 'F', 'C', 'F', 'T']
# *********************
# Gold: ['F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['F', 'F', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']
# *********************
# Gold: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'T']
# Pred: ['T', 'T', 'T', 'T', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'T', 'F']
# *********************
# Gold: ['T', 'F', 'F', 'F', 'F', 'F', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'F', 'T', 'F', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'F', 'C', 'T', 'T', 'T', 'T', 'F', 'F', 'T', 'F', 'F', 'T', 'T']
# *********************
# Gold: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'T']
# Pred: ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'F', 'T', 'T', 'F', 'F', 'A', 'F', 'T']
# *********************

# %%
# 1. Read the eval file
with open("DataFiles/cde.epe") as d_in, \
     open("EvalFiles/eval_gold.epe", "wt") as out:
  for line in d_in:
    sent = json.loads(line)
    sent = ev.map_back_gold(sent)
    json.dump(sent, out)
    out.write("\n")

# %%
# 2. Eval and print to file

# %%
with open("EvalFiles/eval_gold.epe") as f:
  for line in f:
    print(line)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
invs = list(zip(inv_id, inv_src))

# %%
with open("DataFiles/cdd.epe") as f:
  s = [json.loads(line) for line in f]

# %%
with open("negation/cdd.epe") as f:
  s2 = [json.loads(line) for line in f]

# %%
for i in s2:
  if (i["id"], i["source"]) in invs:
    print("\t", i["negations"])
    for n in i["nodes"]:
      print("\t\t", n["form"], "\tNegation: ", end="\n")
      for l in n.get("negation"):
        print("\t\t\t", l, end="\n")
    print("*"*31)
# Out:
# 	 2
# 		 The 	Negation:
# 			 {'id': 25, 'scope': 'The'}
# 			 {'id': 26}
# 		 dinner 	Negation:
# 			 {'id': 25, 'scope': 'dinner'}
# 			 {'id': 26}
# 		 itself 	Negation:
# 			 {'id': 25, 'scope': 'itself'}
# 			 {'id': 26}
# 		 was 	Negation:
# 			 {'id': 25, 'scope': 'was'}
# 			 {'id': 26}
# 		 neither 	Negation:
# 			 {'id': 25, 'cue': 'neither'}
# 			 {'id': 26}
# 		 well 	Negation:
# 			 {'id': 25, 'scope': 'well'}
# 			 {'id': 26}
# 		 served 	Negation:
# 			 {'id': 25, 'scope': 'served', 'event': 'served'}
# 			 {'id': 26}
# 		 nor 	Negation:
# 			 {'id': 25, 'cue': 'nor'}
# 			 {'id': 26}
# 		 well 	Negation:
# 			 {'id': 25, 'scope': 'well'}
# 			 {'id': 26}
# 		 cooked 	Negation:
# 			 {'id': 25, 'scope': 'cooked', 'event': 'cooked'}
# 			 {'id': 26}
# 		 , 	Negation:
# 			 {'id': 25}
# 			 {'id': 26}
# 		 and 	Negation:
# 			 {'id': 25}
# 			 {'id': 26}
# 		 the 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'the'}
# 		 gloomy 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'gloomy'}
# 		 presence 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'presence'}
# 		 of 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'of'}
# 		 the 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'the'}
# 		 taciturn 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'taciturn'}
# 		 servant 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'servant'}
# 		 did 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'did'}
# 		 not 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'cue': 'not'}
# 		 help 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'help', 'event': 'help'}
# 		 to 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'to'}
# 		 enliven 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'enliven'}
# 		 us 	Negation:
# 			 {'id': 25}
# 			 {'id': 26, 'scope': 'us'}
# 		 . 	Negation:
# 			 {'id': 25}
# 			 {'id': 26}
# *******************************
# 	 1
# 		 There 	Negation:
# 			 {'id': 45, 'scope': 'There'}
# 		 are 	Negation:
# 			 {'id': 45, 'scope': 'are'}
# 		 no 	Negation:
# 			 {'id': 45, 'cue': 'no'}
# 		 footsteps 	Negation:
# 			 {'id': 45, 'scope': 'footsteps', 'event': 'footsteps'}
# 		 nor 	Negation:
# 			 {'id': 45, 'cue': 'nor'}
# 		 any 	Negation:
# 			 {'id': 45, 'scope': 'any'}
# 		 clue 	Negation:
# 			 {'id': 45, 'scope': 'clue', 'event': 'clue'}
# 		 to 	Negation:
# 			 {'id': 45, 'scope': 'to'}
# 		 the 	Negation:
# 			 {'id': 45, 'scope': 'the'}
# 		 criminals 	Negation:
# 			 {'id': 45, 'scope': 'criminals'}
# 		 . 	Negation:
# 			 {'id': 45}
# 		 '' 	Negation:
# 			 {'id': 45}
# *******************************
# 	 1
# 		 It 	Negation:
# 			 {'id': 50}
# 		 was 	Negation:
# 			 {'id': 50}
# 		 after 	Negation:
# 			 {'id': 50}
# 		 nine 	Negation:
# 			 {'id': 50}
# 		 this 	Negation:
# 			 {'id': 50}
# 		 morning 	Negation:
# 			 {'id': 50}
# 		 when 	Negation:
# 			 {'id': 50, 'scope': 'when'}
# 		 we 	Negation:
# 			 {'id': 50, 'scope': 'we'}
# 		 reached 	Negation:
# 			 {'id': 50}
# 		 his 	Negation:
# 			 {'id': 50}
# 		 house 	Negation:
# 			 {'id': 50}
# 		 and 	Negation:
# 			 {'id': 50}
# 		 found 	Negation:
# 			 {'id': 50, 'scope': 'found', 'event': 'found'}
# 		 neither 	Negation:
# 			 {'id': 50, 'cue': 'neither'}
# 		 you 	Negation:
# 			 {'id': 50, 'scope': 'you'}
# 		 nor 	Negation:
# 			 {'id': 50, 'cue': 'nor'}
# 		 anyone 	Negation:
# 			 {'id': 50, 'scope': 'anyone'}
# 		 else 	Negation:
# 			 {'id': 50, 'scope': 'else'}
# 		 inside 	Negation:
# 			 {'id': 50, 'scope': 'inside'}
# 		 it 	Negation:
# 			 {'id': 50, 'scope': 'it'}
# 		 . 	Negation:
# 			 {'id': 50}
# *******************************
# 	 2
# 		 `` 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 Remarkable 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 , 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 but 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 by 	Negation:
# 			 {'id': 55, 'cue': 'by'}
# 			 {'id': 56}
# 		 no 	Negation:
# 			 {'id': 55, 'cue': 'no'}
# 			 {'id': 56}
# 		 means 	Negation:
# 			 {'id': 55, 'cue': 'means'}
# 			 {'id': 56}
# 		 impossible 	Negation:
# 			 {'id': 55, 'scope': 'impossible', 'event': 'impossible'}
# 			 {'id': 56, 'cue': 'im', 'scope': 'possible', 'event': 'possible'}
# 		 , 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 '' 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 said 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 Holmes 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 , 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 smiling 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# 		 . 	Negation:
# 			 {'id': 55}
# 			 {'id': 56}
# *******************************
# 	 1
# 		 From 	Negation:
# 			 {'id': 165, 'scope': 'From'}
# 		 that 	Negation:
# 			 {'id': 165, 'scope': 'that'}
# 		 day 	Negation:
# 			 {'id': 165, 'scope': 'day'}
# 		 they 	Negation:
# 			 {'id': 165, 'scope': 'they'}
# 		 were 	Negation:
# 			 {'id': 165, 'scope': 'were'}
# 		 seen 	Negation:
# 			 {'id': 165, 'scope': 'seen', 'event': 'seen'}
# 		 no 	Negation:
# 			 {'id': 165, 'cue': 'no'}
# 		 more 	Negation:
# 			 {'id': 165, 'cue': 'more'}
# 		 in 	Negation:
# 			 {'id': 165, 'scope': 'in'}
# 		 England 	Negation:
# 			 {'id': 165, 'scope': 'England'}
# 		 . 	Negation:
# 			 {'id': 165}
# *******************************

# %%
def map_node(id, form, lemma, xpos):
  return {"id": str(id), 
          "form": form, 
          "properties": {"lemma": lemma, "xpos": xpos}}

def map_back(sentence):
  out = sentence.copy()
  
  form = out.pop("form")
  lemma = out.pop("lemma")
  xpos = out.pop("xpos")
  cue = out.pop("cue")
  scope = out.pop("scope")
  negation = out.pop("negation")

  nodes = []

  if sentence["negations"] == 0:
    for i in range(len(form)):
      nodes.append(map_node(i, form[i], lemma[i], xpos[i]))
  
  else:
    for i in range(len(form)):
      node = map_node(i, form[i], lemma[i], xpos[i])
      if negation[i] == "T":
        node["negation"] = [{"id": 0}]
      elif negation[i] == "F":
        node["negation"] = [{"id": 0, "scope": scope[i]}]
      elif negation[i] == "C":
        node["negation"] = [{"id": 0, "cue": cue[i]}]
      elif negation[i] == "A":
        node["negation"] = [{"id": 0, "cue": cue[i], "scope": scope[i]}]
      else:
        node["negation"] = [{"id": 0}]

      nodes.append(node)

  out["nodes"] = nodes
  return out

def pred_map_back(sentence):
  out = sentence.copy()
  
  form = out.pop("form")
  lemma = out.pop("lemma")
  xpos = out.pop("xpos")
  cue = out.pop("cue")
  scope = out.pop("scope")
  negation = out.pop("negation")

  nodes = []

  if sentence["negations"] == 0:
    for i in range(len(form)):
      nodes.append(map_node(i, form[i], lemma[i], xpos[i]))
  
  else:
    for i in range(len(form)):
      node = map_node(i, form[i], lemma[i], xpos[i])
      if negation[i] == "T":
        node["negation"] = [{"id": 0}]
      elif negation[i] == "F":
        node["negation"] = [{"id": 0, "scope": scope[i]}]
      elif negation[i] == "C":
        node["negation"] = [{"id": 0, "cue": cue[i]}]
      elif negation[i] == "A":
        node["negation"] = [{"id": 0, "cue": cue[i], "scope": scope[i]}]
      else:
        node["negation"] = [{"id": 0}]

      nodes.append(node)

  out["nodes"] = nodes
  return out

# %%
s4 = map_back(s[4])

# %%
s4
# Out:
# {'id': '4',
#  'negations': 0,
#  'nodes': [{'form': 'Suddenly',
#    'id': '0',
#    'properties': {'lemma': 'Suddenly', 'xpos': 'RB'}},
#   {'form': 'he', 'id': '1', 'properties': {'lemma': 'he', 'xpos': 'PRP'}},
#   {'form': 'turned',
#    'id': '2',
#    'properties': {'lemma': 'turn', 'xpos': 'VBD'}},
#   {'form': 'upon', 'id': '3', 'properties': {'lemma': 'upon', 'xpos': 'IN'}},
#   {'form': 'me', 'id': '4', 'properties': {'lemma': 'me', 'xpos': 'PRP'}},
#   {'form': 'with', 'id': '5', 'properties': {'lemma': 'with', 'xpos': 'IN'}},
#   {'form': 'a', 'id': '6', 'properties': {'lemma': 'a', 'xpos': 'DT'}},
#   {'form': 'mischievous',
#    'id': '7',
#    'properties': {'lemma': 'mischievous', 'xpos': 'JJ'}},
#   {'form': 'twinkle',
#    'id': '8',
#    'properties': {'lemma': 'twinkle', 'xpos': 'NN'}},
#   {'form': 'in', 'id': '9', 'properties': {'lemma': 'in', 'xpos': 'IN'}},
#   {'form': 'his', 'id': '10', 'properties': {'lemma': 'his', 'xpos': 'PRP$'}},
#   {'form': 'eyes', 'id': '11', 'properties': {'lemma': 'eye', 'xpos': 'NNS'}},
#   {'form': '.', 'id': '12', 'properties': {'lemma': '.', 'xpos': '.'}}],
#  'source': 'wisteria01'}

# %%
def test_map(sent):
  has_c_cue = "C" in sent["negation"]
  has_a_cue = "A" in sent["negation"]
  if has_c_cue or has_a_cue:
# Out:
# {'cue': ['', '', '', '', '', '', '', '', ''],
#  'form': ['1.',
#   'The',
#   'Singular',
#   'Experience',
#   'of',
#   'Mr.',
#   'John',
#   'Scott',
#   'Eccles'],
#  'id': '0',
#  'lemma': ['1.',
#   'The',
#   'Singular',
#   'Experience',
#   'of',
#   'Mr.',
#   'John',
#   'Scott',
#   'Eccles'],
#  'negation': ['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T'],
#  'negations': 0,
#  'scope': ['', '', '', '', '', '', '', '', ''],
#  'source': 'wisteria01',
#  'xpos': ['CD', 'NNP', 'NNP', 'NN', 'IN', 'NNP', 'NNP', 'NNP', 'NNP']}

# %%
if 2:
  print(1)
# Out:
# 1

# %%
import tqdm

# %%
y_hat = torch.tensor([], dtype=torch.long)
y = torch.tensor([], dtype=torch.long)

tp = 0
n = 0

model.eval()
with torch.no_grad():
    for batch in tqdm.tqdm(val_iter):
        y_tilde_b = model(batch.form)
        y_hat_b = y_tilde_b.argmax(dim=-1)
        y_b = batch.label

        tp += (y_hat_b == y_b).nonzero().size(0)
        n += y_b.size(1)

        y_hat = torch.cat((y_hat, y_hat_b.view(-1).cpu()))
        y = torch.cat((y, y_b.view(-1).cpu()))

results_eval = {
    "accuracy": tp / n,
    **runner.get_metrics(y, y_hat)
}
# Out:
# 100%|██████████| 816/816 [00:01<00:00, 485.68it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)

# %%
tss = set(["T", "A"]*20)

# %%
set(["T"]*20).issubset(set("T"))
# Out:
# True

# %% [markdown]
# ### Multiclass confmat

# %%
from sklearn.metrics import multilabel_confusion_matrix

# %%
multilabel_confusion_matrix(y, y_hat, labels=runner.labels)

# %%
xxx = next(iter(val_iter))

# %%
TEXT.process(train.examples[0].text)[0].shape

# %%
xproc = FORM.process([Xtrain.examples[1].form])
cproc = CUE.process([Xtrain.examples[1].cue])

# %%
mx = model.embedding(xproc[0].to(device))
mc = model.embedding(cproc[0].to(device))

# %%
(mx + mc).shape
# Out:
# torch.Size([1, 33, 300])

# %%
xproc[1] == cproc[1]
# Out:
# tensor([True])

# %%
from collections import Counter

# %%
import json

# %%
c = Counter()
with open("DataFiles/cdt.epe") as f:
  for line in f:
    for l in json.loads(line)["negation"]:
      c[l] += 1

# %%
cdev = Counter()
with open("DataFiles/cdd.epe") as f:
  for line in f:
    for l in json.loads(line)["negation"]:
      cdev[l] += 1

# %%
c
# Out:
# Counter({'A': 159, 'C': 843, 'F': 6802, 'T': 61351})

# %%
cdev
# Out:
# Counter({'A': 33, 'C': 146, 'F': 1335, 'T': 12758})

# %%
LABS.vocab.itos
# Out:
# ['<pad>', 'T', 'F', 'C', 'A']

# %%
torch.nn.CrossEntropyLoss()

# %%
(1/159) + (1/843) + (1/6802) + (1/61351)
# Out:
# 0.007638863032973212

# %%
y1 = 159
y2 = 843
y3 = 6802
y4 = 61351

# %%
(y1*y2*y3*y4)/(y2*y3*y4 + y1*y3*y4 + y1*y2*y4 + y1*y2*y3)
# Out:
# 130.9095340083324

# %%
w1 = 130.91/159
w2 = 130.91/843
w3 = 130.91/6802
w4 = 130.91/61351

# %%
w1+w2+w3+w4
# Out:
# 1.0000035596465233

# %%
ID = data.RawField(preprocessing=lambda x: int(x))
SRC = data.RawField()
NEGS = data.RawField(preprocessing=lambda x: int(x))
FORM = data.Field(batch_first=True, include_lengths=True)
LEMMA = data.RawField()
XPOS = data.RawField()
LABS = data.Field(batch_first=True, unk_token=None)
CUE = data.Field(batch_first=True)
SCOPE = data.RawField()

fields = {
    "id": ("id", ID),
    "source": ("source", SRC),
    "negations": ("negations", NEGS),
    "form": ("form", FORM),
    "lemma": ("lemma", LEMMA),
    "xpos": ("xpos", XPOS),
    "negation": ("label", LABS),
    "cue": ("cue", CUE),
    "scope": ("scope", SCOPE),
}

Xtrain, Xdev = NSR.StarSEM2012.splits(
    "DataFiles",
    fields=fields,
    test=None
)

FORM.build_vocab(Xtrain,
                  max_size=None,
                  min_freq=1,
                  vectors=None)

# %%
FORM.vocab.stoi
# Out:
# defaultdict(<function torchtext.vocab._default_unk_index>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              ',': 2,
#              '.': 3,
#              'the': 4,
#              'I': 5,
#              'of': 6,
#              'and': 7,
#              '``': 8,
#              "''": 9,
#              'to': 10,
#              'a': 11,
#              'that': 12,
#              'in': 13,
#              'it': 14,
#              'was': 15,
#              'you': 16,
#              'he': 17,
#              'is': 18,
#              'his': 19,
#              'have': 20,
#              '?': 21,
#              'had': 22,
#              'not': 23,
#              'my': 24,
#              'with': 25,
#              'which': 26,
#              'for': 27,
#              'as': 28,
#              'we': 29,
#              'me': 30,
#              'at': 31,
#              'be': 32,
#              'upon': 33,
#              'this': 34,
#              'him': 35,
#              'but': 36,
#              'from': 37,
#              'said': 38,
#              'no': 39,
#              'Sir': 40,
#              "'s": 41,
#              'The': 42,
#              'one': 43,
#              'been': 44,
#              'It': 45,
#              'could': 46,
#              'all': 47,
#              'man': 48,
#              'there': 49,
#              'on': 50,
#              'do': 51,
#              'Holmes': 52,
#              'so': 53,
#              'were': 54,
#              'are': 55,
#              'an': 56,
#              '!': 57,
#              'our': 58,
#              'would': 59,
#              'He': 60,
#              'by': 61,
#              'us': 62,
#              'very': 63,
#              '--': 64,
#              'your': 65,
#              'will': 66,
#              'out': 67,
#              'has': 68,
#              'moor': 69,
#              'Henry': 70,
#              'if': 71,
#              'should': 72,
#              'who': 73,
#              'But': 74,
#              'more': 75,
#              'some': 76,
#              'her': 77,
#              'what': 78,
#              'up': 79,
#              'can': 80,
#              'sir': 81,
#              'or': 82,
#              'know': 83,
#              'We': 84,
#              'You': 85,
#              'Watson': 86,
#              'And': 87,
#              'No': 88,
#              'when': 89,
#              'Baskerville': 90,
#              'see': 91,
#              'There': 92,
#              'she': 93,
#              'into': 94,
#              'over': 95,
#              'Dr.': 96,
#              'about': 97,
#              'down': 98,
#              'them': 99,
#              'did': 100,
#              'than': 101,
#              "n't": 102,
#              'any': 103,
#              'may': 104,
#              'then': 105,
#              'Charles': 106,
#              'before': 107,
#              'think': 108,
#              'must': 109,
#              'am': 110,
#              'Mortimer': 111,
#              'now': 112,
#              'only': 113,
#              'they': 114,
#              'What': 115,
#              'own': 116,
#              'time': 117,
#              'might': 118,
#              'face': 119,
#              'Barrymore': 120,
#              'here': 121,
#              'A': 122,
#              'say': 123,
#              'two': 124,
#              'much': 125,
#              'came': 126,
#              'come': 127,
#              'eyes': 128,
#              'other': 129,
#              'night': 130,
#              'tell': 131,
#              'where': 132,
#              'Mr.': 133,
#              'back': 134,
#              'last': 135,
#              'nothing': 136,
#              'Stapleton': 137,
#              'If': 138,
#              'friend': 139,
#              'long': 140,
#              'never': 141,
#              'That': 142,
#              'heard': 143,
#              'how': 144,
#              'such': 145,
#              'saw': 146,
#              'these': 147,
#              'Well': 148,
#              'go': 149,
#              'their': 150,
#              'Hall': 151,
#              'light': 152,
#              'until': 153,
#              ';': 154,
#              'Then': 155,
#              'Yes': 156,
#              'away': 157,
#              'again': 158,
#              'little': 159,
#              'death': 160,
#              'way': 161,
#              'My': 162,
#              'great': 163,
#              'like': 164,
#              'after': 165,
#              'hound': 166,
#              'house': 167,
#              'made': 168,
#              'matter': 169,
#              'old': 170,
#              'good': 171,
#              'its': 172,
#              'most': 173,
#              'day': 174,
#              'looked': 175,
#              'place': 176,
#              'through': 177,
#              'yet': 178,
#              'well': 179,
#              'once': 180,
#              'thought': 181,
#              'case': 182,
#              'morning': 183,
#              'round': 184,
#              'since': 185,
#              'those': 186,
#              'against': 187,
#              'first': 188,
#              'make': 189,
#              'seen': 190,
#              'London': 191,
#              'side': 192,
#              'find': 193,
#              'baronet': 194,
#              'left': 195,
#              'turned': 196,
#              'asked': 197,
#              'dark': 198,
#              'mind': 199,
#              'still': 200,
#              'In': 201,
#              'black': 202,
#              'seemed': 203,
#              'done': 204,
#              'lay': 205,
#              'name': 206,
#              'off': 207,
#              'same': 208,
#              'something': 209,
#              'take': 210,
#              'told': 211,
#              'without': 212,
#              'anything': 213,
#              'ever': 214,
#              'family': 215,
#              'found': 216,
#              'hand': 217,
#              'hands': 218,
#              'right': 219,
#              'why': 220,
#              'wife': 221,
#              'woman': 222,
#              'also': 223,
#              'door': 224,
#              'get': 225,
#              'window': 226,
#              'Sherlock': 227,
#              'far': 228,
#              'few': 229,
#              'help': 230,
#              'shall': 231,
#              "'": 232,
#              'doubt': 233,
#              'himself': 234,
#              'life': 235,
#              'clear': 236,
#              'fellow': 237,
#              'instant': 238,
#              'stood': 239,
#              'thing': 240,
#              'Now': 241,
#              'cried': 242,
#              'dear': 243,
#              'give': 244,
#              'lady': 245,
#              'took': 246,
#              'As': 247,
#              'How': 248,
#              'Why': 249,
#              '`': 250,
#              'behind': 251,
#              'knew': 252,
#              'passed': 253,
#              'This': 254,
#              'When': 255,
#              'end': 256,
#              'every': 257,
#              'head': 258,
#              'heart': 259,
#              'put': 260,
#              'together': 261,
#              'whom': 262,
#              'At': 263,
#              'letter': 264,
#              'small': 265,
#              'words': 266,
#              'Mrs.': 267,
#              'So': 268,
#              'across': 269,
#              'gave': 270,
#              'indeed': 271,
#              'myself': 272,
#              'rather': 273,
#              'really': 274,
#              "'ll": 275,
#              'always': 276,
#              'answer': 277,
#              'between': 278,
#              'certainly': 279,
#              'front': 280,
#              'gone': 281,
#              'path': 282,
#              'sound': 283,
#              'too': 284,
#              'To': 285,
#              'both': 286,
#              'however': 287,
#              'moment': 288,
#              'room': 289,
#              'set': 290,
#              'whole': 291,
#              'Did': 292,
#              'His': 293,
#              'already': 294,
#              'being': 295,
#              'brother': 296,
#              'does': 297,
#              'evening': 298,
#              'hear': 299,
#              'ran': 300,
#              'strange': 301,
#              'understand': 302,
#              'word': 303,
#              'She': 304,
#              'Street': 305,
#              'better': 306,
#              'brought': 307,
#              'cry': 308,
#              'interest': 309,
#              'people': 310,
#              'point': 311,
#              'taken': 312,
#              'went': 313,
#              'within': 314,
#              'Do': 315,
#              'course': 316,
#              'days': 317,
#              'facts': 318,
#              'followed': 319,
#              'going': 320,
#              'just': 321,
#              'perhaps': 322,
#              'quite': 323,
#              'voice': 324,
#              'walk': 325,
#              'wish': 326,
#              'world': 327,
#              'Is': 328,
#              'On': 329,
#              'able': 330,
#              'enough': 331,
#              'even': 332,
#              'fear': 333,
#              'gray': 334,
#              'next': 335,
#              'poor': 336,
#              'reason': 337,
#              'return': 338,
#              'three': 339,
#              'yourself': 340,
#              "'ve": 341,
#              'Grimpen': 342,
#              'another': 343,
#              'ask': 344,
#              'body': 345,
#              'country': 346,
#              'darkness': 347,
#              'direction': 348,
#              'held': 349,
#              'hour': 350,
#              'kind': 351,
#              'leave': 352,
#              'look': 353,
#              'mean': 354,
#              'sat': 355,
#              'sure': 356,
#              'though': 357,
#              'towards': 358,
#              'while': 359,
#              'One': 360,
#              'alone': 361,
#              'along': 362,
#              'among': 363,
#              'believe': 364,
#              'cab': 365,
#              'chance': 366,
#              'coming': 367,
#              'convict': 368,
#              'got': 369,
#              'half': 370,
#              'hill': 371,
#              'home': 372,
#              'known': 373,
#              'many': 374,
#              'new': 375,
#              'ready': 376,
#              'seems': 377,
#              'several': 378,
#              'showed': 379,
#              'truth': 380,
#              'under': 381,
#              'white': 382,
#              'Hugo': 383,
#              'Lyons': 384,
#              'They': 385,
#              'anyone': 386,
#              'danger': 387,
#              'deep': 388,
#              'gentleman': 389,
#              'paper': 390,
#              'read': 391,
#              'rose': 392,
#              'save': 393,
#              'sister': 394,
#              'story': 395,
#              'things': 396,
#              'whether': 397,
#              'young': 398,
#              ':': 399,
#              'For': 400,
#              'Frankland': 401,
#              'Not': 402,
#              'With': 403,
#              'business': 404,
#              'either': 405,
#              'glad': 406,
#              'ground': 407,
#              'late': 408,
#              'least': 409,
#              'low': 410,
#              'run': 411,
#              'swear': 412,
#              'walked': 413,
#              'work': 414,
#              'Coombe': 415,
#              'Tracey': 416,
#              'air': 417,
#              'because': 418,
#              'boot': 419,
#              'ca': 420,
#              'call': 421,
#              'doing': 422,
#              'feel': 423,
#              'feet': 424,
#              'figure': 425,
#              'huge': 426,
#              'position': 427,
#              'report': 428,
#              'waiting': 429,
#              'By': 430,
#              'alley': 431,
#              'boy': 432,
#              'broke': 433,
#              'butler': 434,
#              'evidence': 435,
#              'given': 436,
#              'hard': 437,
#              'hotel': 438,
#              'kept': 439,
#              'large': 440,
#              'let': 441,
#              'means': 442,
#              'met': 443,
#              'moon': 444,
#              'near': 445,
#              'reached': 446,
#              'remember': 447,
#              'standing': 448,
#              'stick': 449,
#              'surprise': 450,
#              'God': 451,
#              'Have': 452,
#              'Our': 453,
#              'cold': 454,
#              'creature': 455,
#              'died': 456,
#              'else': 457,
#              'friends': 458,
#              'full': 459,
#              'heavy': 460,
#              'hours': 461,
#              'husband': 462,
#              'hut': 463,
#              'lived': 464,
#              'object': 465,
#              'opened': 466,
#              'ourselves': 467,
#              'part': 468,
#              'running': 469,
#              'secret': 470,
#              'show': 471,
#              'strong': 472,
#              'struck': 473,
#              'years': 474,
#              'Because': 475,
#              'Chapter': 476,
#              'Exactly': 477,
#              'From': 478,
#              'Her': 479,
#              'House': 480,
#              'assure': 481,
#              'beard': 482,
#              'candle': 483,
#              'dog': 484,
#              'entirely': 485,
#              'high': 486,
#              'imagine': 487,
#              'keep': 488,
#              'learned': 489,
#              'men': 490,
#              'possible': 491,
#              'question': 492,
#              'returned': 493,
#              'road': 494,
#              'seem': 495,
#              'sent': 496,
#              'slowly': 497,
#              'someone': 498,
#              'stone': 499,
#              'straight': 500,
#              'surely': 501,
#              'tonight': 502,
#              'track': 503,
#              'trouble': 504,
#              'visit': 505,
#              'Merripit': 506,
#              'Selden': 507,
#              'Very': 508,
#              'breakfast': 509,
#              'connection': 510,
#              'cut': 511,
#              'dead': 512,
#              'distance': 513,
#              'drive': 514,
#              'during': 515,
#              'earth': 516,
#              'escaped': 517,
#              'evidently': 518,
#              'evil': 519,
#              'explanation': 520,
#              'five': 521,
#              'hardly': 522,
#              'having': 523,
#              'interesting': 524,
#              'less': 525,
#              'lonely': 526,
#              'looking': 527,
#              'love': 528,
#              'meet': 529,
#              'mine': 530,
#              'minutes': 531,
#              'none': 532,
#              'nor': 533,
#              'occurred': 534,
#              'outside': 535,
#              'possibly': 536,
#              'present': 537,
#              'questions': 538,
#              'second': 539,
#              'sight': 540,
#              'silent': 541,
#              'stared': 542,
#              'suppose': 543,
#              'talk': 544,
#              'true': 545,
#              'yew': 546,
#              'Baskervilles': 547,
#              'Here': 548,
#              'Your': 549,
#              'almost': 550,
#              'became': 551,
#              'broken': 552,
#              'cases': 553,
#              'close': 554,
#              'date': 555,
#              'exactly': 556,
#              'fact': 557,
#              'father': 558,
#              'fog': 559,
#              'further': 560,
#              'message': 561,
#              'person': 562,
#              'reasons': 563,
#              'rest': 564,
#              'rocks': 565,
#              'singular': 566,
#              'spoke': 567,
#              'surprised': 568,
#              'table': 569,
#              'therefore': 570,
#              'thin': 571,
#              'town': 572,
#              'turn': 573,
#              'waited': 574,
#              'All': 575,
#              'Baker': 576,
#              'Come': 577,
#              'Devonshire': 578,
#              'Mire': 579,
#              'Miss': 580,
#              'Oh': 581,
#              'Stapletons': 582,
#              'Where': 583,
#              'boots': 584,
#              'broad': 585,
#              'certain': 586,
#              'complete': 587,
#              'corner': 588,
#              'devil': 589,
#              'dull': 590,
#              'expression': 591,
#              'fell': 592,
#              'gate': 593,
#              'granite': 594,
#              'green': 595,
#              'hall': 596,
#              'hold': 597,
#              'hope': 598,
#              'horror': 599,
#              'latter': 600,
#              'led': 601,
#              'legend': 602,
#              'line': 603,
#              'master': 604,
#              'meant': 605,
#              'miles': 606,
#              'mire': 607,
#              'observe': 608,
#              'observed': 609,
#              'pair': 610,
#              'practical': 611,
#              'private': 612,
#              'rooms': 613,
#              'send': 614,
#              'shadow': 615,
#              'short': 616,
#              'soon': 617,
#              'speak': 618,
#              'stranger': 619,
#              'suspicions': 620,
#              'swiftly': 621,
#              'ten': 622,
#              'terrible': 623,
#              'today': 624,
#              'trace': 625,
#              'twice': 626,
#              'view': 627,
#              'wind': 628,
#              'James': 629,
#              'L.': 630,
#              'Lestrade': 631,
#              'Look': 632,
#              'Times': 633,
#              'Was': 634,
#              'affair': 635,
#              'amid': 636,
#              'around': 637,
#              'best': 638,
#              'brown': 639,
#              'character': 640,
#              'companion': 641,
#              'confess': 642,
#              'conversation': 643,
#              'curious': 644,
#              'dare': 645,
#              'deal': 646,
#              'detective': 647,
#              'difficult': 648,
#              'distant': 649,
#              'drew': 650,
#              'drove': 651,
#              'each': 652,
#              'evident': 653,
#              'example': 654,
#              'farther': 655,
#              'felt': 656,
#              'folk': 657,
#              'food': 658,
#              'foot': 659,
#              'goes': 660,
#              'heir': 661,
#              'huts': 662,
#              'idea': 663,
#              'importance': 664,
#              'inside': 665,
#              'interview': 666,
#              'lamp': 667,
#              'likely': 668,
#              'live': 669,
#              'lost': 670,
#              'melancholy': 671,
#              'nature': 672,
#              'nerves': 673,
#              'obvious': 674,
#              'open': 675,
#              'picture': 676,
#              'power': 677,
#              'presume': 678,
#              'promise': 679,
#              'public': 680,
#              'reach': 681,
#              'roof': 682,
#              'shot': 683,
#              'sign': 684,
#              'spot': 685,
#              'started': 686,
#              'steps': 687,
#              'suddenly': 688,
#              'taking': 689,
#              'telegram': 690,
#              'thick': 691,
#              'tomorrow': 692,
#              'trees': 693,
#              'trust': 694,
#              'unless': 695,
#              'use': 696,
#              'vague': 697,
#              'visitor': 698,
#              'walking': 699,
#              'wall': 700,
#              'windows': 701,
#              'yellow': 702,
#              'yonder': 703,
#              'England': 704,
#              'Laura': 705,
#              'Who': 706,
#              'account': 707,
#              'affairs': 708,
#              'allow': 709,
#              'animal': 710,
#              'answered': 711,
#              'appearance': 712,
#              'appeared': 713,
#              'appointment': 714,
#              'asking': 715,
#              'bad': 716,
#              'beyond': 717,
#              'caught': 718,
#              'centre': 719,
#              'county': 720,
#              'crime': 721,
#              'driving': 722,
#              'early': 723,
#              'everything': 724,
#              'fallen': 725,
#              'false': 726,
#              'fears': 727,
#              'features': 728,
#              'flushed': 729,
#              'follow': 730,
#              'forget': 731,
#              'fortune': 732,
#              'foul': 733,
#              'glanced': 734,
#              'gloom': 735,
#              'guess': 736,
#              'hat': 737,
#              'hills': 738,
#              'hundred': 739,
#              'important': 740,
#              'impression': 741,
#              'inquiry': 742,
#              'keeping': 743,
#              'lower': 744,
#              'making': 745,
#              'marks': 746,
#              'middle': 747,
#              'modern': 748,
#              'narrative': 749,
#              'naturalist': 750,
#              "o'clock": 751,
#              'order': 752,
#              'pale': 753,
#              'past': 754,
#              'pleasure': 755,
#              'police': 756,
#              'presence': 757,
#              'purpose': 758,
#              'sake': 759,
#              'sank': 760,
#              'scene': 761,
#              'sharp': 762,
#              'shone': 763,
#              'shoulders': 764,
#              'signs': 765,
#              'silence': 766,
#              'situation': 767,
#              'skull': 768,
#              'soul': 769,
#              'sprang': 770,
#              'station': 771,
#              'step': 772,
#              'study': 773,
#              'sudden': 774,
#              'suggest': 775,
#              'sun': 776,
#              'telling': 777,
#              'throat': 778,
#              'tragedy': 779,
#              'used': 780,
#              'yards': 781,
#              'yesterday': 782,
#              'Hotel': 783,
#              'Let': 784,
#              'Only': 785,
#              'Regent': 786,
#              'Surely': 787,
#              'Thank': 788,
#              'These': 789,
#              'Yet': 790,
#              'above': 791,
#              'afterwards': 792,
#              'amazement': 793,
#              'arms': 794,
#              'attention': 795,
#              'beast': 796,
#              'beautiful': 797,
#              'began': 798,
#              'bring': 799,
#              'burned': 800,
#              'cabman': 801,
#              'carry': 802,
#              'cause': 803,
#              'chair': 804,
#              'confidence': 805,
#              'dinner': 806,
#              'doctor': 807,
#              'dreadful': 808,
#              'duty': 809,
#              'ears': 810,
#              'easily': 811,
#              'empty': 812,
#              'exceedingly': 813,
#              'experience': 814,
#              'explain': 815,
#              'explained': 816,
#              'extraordinary': 817,
#              'eye': 818,
#              'fine': 819,
#              'following': 820,
#              'forward': 821,
#              'four': 822,
#              'game': 823,
#              'gazed': 824,
#              'gentlemen': 825,
#              'getting': 826,
#              'glimpse': 827,
#              'handsome': 828,
#              'happy': 829,
#              'hospital': 830,
#              'hung': 831,
#              'impossible': 832,
#              'information': 833,
#              'initials': 834,
#              'journey': 835,
#              'living': 836,
#              'mark': 837,
#              'mentioned': 838,
#              'missing': 839,
#              'moor-gate': 840,
#              'moorland': 841,
#              'natural': 842,
#              'need': 843,
#              'neighbours': 844,
#              'net': 845,
#              'number': 846,
#              'occasion': 847,
#              'particular': 848,
#              'placed': 849,
#              'plans': 850,
#              'play': 851,
#              'pleasant': 852,
#              'pointed': 853,
#              'points': 854,
#              'raised': 855,
#              'rare': 856,
#              'revolver': 857,
#              'risk': 858,
#              'serious': 859,
#              'shape': 860,
#              'sometimes': 861,
#              'sorry': 862,
#              'sort': 863,
#              'stopped': 864,
#              'supernatural': 865,
#              'thunder': 866,
#              'tor': 867,
#              'unable': 868,
#              'unknown': 869,
#              'want': 870,
#              'watch': 871,
#              'wicked': 872,
#              'wild': 873,
#              'wonder': 874,
#              'wrong': 875,
#              'Charing': 876,
#              'Cross': 877,
#              'Every': 878,
#              'Halloa': 879,
#              'Just': 880,
#              'Northumberland': 881,
#              'Nothing': 882,
#              'Tell': 883,
#              'accept': 884,
#              'address': 885,
#              'adventure': 886,
#              'age': 887,
#              'beneath': 888,
#              'blood': 889,
#              'boulders': 890,
#              'calling': 891,
#              'carefully': 892,
#              'change': 893,
#              'clouds': 894,
#              'corridor': 895,
#              'countryside': 896,
#              'covered': 897,
#              'cunning': 898,
#              'deeply': 899,
#              'definite': 900,
#              'difficulty': 901,
#              'dining-room': 902,
#              'eager': 903,
#              'entered': 904,
#              'escape': 905,
#              'estate': 906,
#              'events': 907,
#              'examine': 908,
#              'excuse': 909,
#              'finding': 910,
#              'fingers': 911,
#              'footsteps': 912,
#              'forced': 913,
#              'forever': 914,
#              'fresh': 915,
#              'glance': 916,
#              'grim': 917,
#              'happened': 918,
#              'heads': 919,
#              'holding': 920,
#              'hunt': 921,
#              'incredible': 922,
#              'keen': 923,
#              'knowledge': 924,
#              'laid': 925,
#              'leaned': 926,
#              'lie': 927,
#              'lips': 928,
#              'manner': 929,
#              'medical': 930,
#              'mention': 931,
#              'months': 932,
#              'move': 933,
#              'mystery': 934,
#              'necessary': 935,
#              'notice': 936,
#              'ordinary': 937,
#              'page': 938,
#              'passage': 939,
#              'plain': 940,
#              'pocket': 941,
#              'practice': 942,
#              'prevent': 943,
#              'problem': 944,
#              'professional': 945,
#              'pursuit': 946,
#              'red': 947,
#              'refused': 948,
#              'remain': 949,
#              'remarked': 950,
#              'rise': 951,
#              'rising': 952,
#              'sense': 953,
#              'shoulder': 954,
#              'shown': 955,
#              'simple': 956,
#              'single': 957,
#              'sitting': 958,
#              'sky': 959,
#              'smoke': 960,
#              'spent': 961,
#              'stand': 962,
#              'stay': 963,
#              'suggested': 964,
#              'tall': 965,
#              'top': 966,
#              'trap': 967,
#              'uncle': 968,
#              'unhappy': 969,
#              'unlikely': 970,
#              'wagonette': 971,
#              'watched': 972,
#              'whence': 973,
#              'whose': 974,
#              'worth': 975,
#              'written': 976,
#              'yours': 977,
#              '(': 978,
#              ')': 979,
#              'Are': 980,
#              'Cartwright': 981,
#              'Good': 982,
#              'Has': 983,
#              'John': 984,
#              'Nature': 985,
#              'Of': 986,
#              'Some': 987,
#              'Tor': 988,
#              'acquaintance': 989,
#              'action': 990,
#              'active': 991,
#              'agent': 992,
#              'ago': 993,
#              'appears': 994,
#              'approached': 995,
#              'article': 996,
#              'become': 997,
#              'becoming': 998,
#              'beg': 999,
#              ...})

# %%
FORM.vocab._default_unk_index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-35588b793467> in <module>()
# ----> 1 FORM.vocab._default_unk_index
#
# AttributeError: 'Vocab' object has no attribute '_default_unk_index'

# %%
torchtext.vocab._default_unk_index
# Out:
# <function torchtext.vocab._default_unk_index>

# %%
with open
