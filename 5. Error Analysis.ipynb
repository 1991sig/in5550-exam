# %%
# !pip install apache-beam --upgrade
# !pip install apache-beam[interactive]

# %%
import apache_beam as beam
from apache_beam.runners.interactive import interactive_runner
import apache_beam.runners.interactive.interactive_beam as ib
from collections import defaultdict, ChainMap
import json
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
import numpy as np

# %%
# %cd drive/My Drive/in5550-exam
# Out:
# /content/drive/My Drive/in5550-exam

# %%
def calculate_metrics(x):
  m = confusion_matrix(x.get("negation"), x.get("pred"), 
                             labels=["T", "F", "C", "A"])
  
  x["scopelen"] = len([s for s in x["scope"] if len(s) > 0])
  x["cuelen"] = len([s for s in x["cue"] if len(s) > 0])

  x["length"] = len(x["form"])
  n_corr = float(np.trace(m))
  x["acc"] = n_corr/x["length"]
  x["precision"] = float(precision_score(x.get("negation"), x.get("pred"), 
                                         labels=["T", "F", "C", "A"],
                                         average="macro", 
                                         zero_division=1))
  
  x["recall"] = float(recall_score(x.get("negation"), x.get("pred"), 
                                   labels=["T", "F", "C", "A"],
                                   average="macro",
                                   zero_division=1))
  
  x["mac_f1"] = float(f1_score(x.get("negation"), x.get("pred"), 
                               labels=["T", "F", "C", "A"],
                               average="macro", 
                               zero_division=1))

  return x

# %%
p = beam.Pipeline(interactive_runner.InteractiveRunner())

# %%
gold = (
    p
    | "Read Gold" >> beam.io.ReadFromText("DataFiles/cde.epe")
    | "Convert to Dict" >> beam.Map(json.loads)
    | "Extract Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
    )

# %% [markdown]
# # BiLSTM-C Baseline

# %%
preds_m1 = (
    p
    | "Read Preds" >> beam.io.ReadFromText(
        "Saves/BiLSTM-C/Baseline/eval_pred_corr_tidy.epe"
        )
    | "JSON loads" >> beam.Map(json.loads)
    | "Create Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
    | "Get Preds Only" >> beam.Map(
        lambda x: (x[0], {"pred": x[1]["negation"]})
        )
    )

res1 = (
    {"gold": gold, "preds": preds_m1} 
    | "Join" >> beam.CoGroupByKey()
    | "Clean" >> beam.Map(
        lambda x: dict(x[1]["gold"][0], **x[1]["preds"][0])
        )
    | "Calculate Metrics" >> beam.Map(calculate_metrics)
    )

# %% [markdown]
# # BiLSTM-C Baseline - Larger hidden dimension

# %%
preds_m2 = (
    p
    | "Read Preds" >> beam.io.ReadFromText(
        "Saves/BiLSTM-C/Baseline_incr_hidd/eval_pred_corr_tidy.epe"
        )
    | "JSON loads" >> beam.Map(json.loads)
    | "Create Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
    | "Get Preds Only" >> beam.Map(
        lambda x: (x[0], {"pred": x[1]["negation"]})
        )
    )

res2 = (
    {"gold": gold, "preds": preds_m2} 
    | "Join" >> beam.CoGroupByKey()
    | "Clean" >> beam.Map(
        lambda x: dict(x[1]["gold"][0], **x[1]["preds"][0])
        )
    | "Calculate Metrics" >> beam.Map(calculate_metrics)
    )

# %% [markdown]
# # BiLSTM-CE - BERT embeddings

# %%
preds_m3 = (
    p
    | "Read Preds" >> beam.io.ReadFromText(
        "Saves/BiLSTM-CE/BERT_base/eval_pred_corr_tidy.epe"
        )
    | "JSON loads" >> beam.Map(json.loads)
    | "Create Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
    | "Get Preds Only" >> beam.Map(
        lambda x: (x[0], {"pred": x[1]["negation"]})
        )
    )

res3 = (
    {"gold": gold, "preds": preds_m3} 
    | "Join" >> beam.CoGroupByKey()
    | "Clean" >> beam.Map(
        lambda x: dict(x[1]["gold"][0], **x[1]["preds"][0])
        )
    | "Calculate Metrics" >> beam.Map(calculate_metrics)
    )

# %%
result = p.run()
res_out1 = result.get(res1)
res_out2 = result.get(res2)
res_out3 = result.get(res3)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="662pt" height="1056pt"
#  viewBox="0.00 0.00 662.00 1056.19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1052.1869)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-1052.1869 658,-1052.1869 658,4 -4,4"/>
# <!-- Cell 30: Read Gold -->
# <g id="node1" class="node">
# <title>Cell 30: Read Gold</title>
# <polygon fill="none" stroke="#0000ff" points="304.5,-904.1869 176.5,-904.1869 176.5,-868.1869 304.5,-868.1869 304.5,-904.1869"/>
# <text text-anchor="middle" x="240.5" y="-882.4869" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 30: Read Gold</text>
# </g>
# <!-- pcoll4375 -->
# <g id="node2" class="node">
# <title>pcoll4375</title>
# <ellipse fill="none" stroke="#0000ff" cx="240.5" cy="-814.1869" rx="18" ry="18"/>
# </g>
# <!-- Cell 30: Read Gold&#45;&gt;pcoll4375 -->
# <g id="edge1" class="edge">
# <title>Cell 30: Read Gold&#45;&gt;pcoll4375</title>
# <path fill="none" stroke="#000000" d="M240.5,-868.0182C240.5,-860.3178 240.5,-851.1612 240.5,-842.6035"/>
# <polygon fill="#000000" stroke="#000000" points="244.0001,-842.6001 240.5,-832.6001 237.0001,-842.6002 244.0001,-842.6001"/>
# </g>
# <!-- Cell 30: Convert to Dict -->
# <g id="node3" class="node">
# <title>Cell 30: Convert to Dict</title>
# <polygon fill="none" stroke="#0000ff" points="318,-760.1869 163,-760.1869 163,-724.1869 318,-724.1869 318,-760.1869"/>
# <text text-anchor="middle" x="240.5" y="-738.4869" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 30: Convert to Dict</text>
# </g>
# <!-- pcoll4375&#45;&gt;Cell 30: Convert to Dict -->
# <g id="edge2" class="edge">
# <title>pcoll4375&#45;&gt;Cell 30: Convert to Dict</title>
# <path fill="none" stroke="#000000" d="M240.5,-796.0182C240.5,-788.3178 240.5,-779.1612 240.5,-770.6035"/>
# <polygon fill="#000000" stroke="#000000" points="244.0001,-770.6001 240.5,-760.6001 237.0001,-770.6002 244.0001,-770.6001"/>
# </g>
# <!-- pcoll7082 -->
# <g id="node4" class="node">
# <title>pcoll7082</title>
# <ellipse fill="none" stroke="#0000ff" cx="240.5" cy="-670.1869" rx="18" ry="18"/>
# </g>
# <!-- Cell 30: Convert to Dict&#45;&gt;pcoll7082 -->
# <g id="edge3" class="edge">
# <title>Cell 30: Convert to Dict&#45;&gt;pcoll7082</title>
# <path fill="none" stroke="#000000" d="M240.5,-724.0182C240.5,-716.3178 240.5,-707.1612 240.5,-698.6035"/>
# <polygon fill="#000000" stroke="#000000" points="244.0001,-698.6001 240.5,-688.6001 237.0001,-698.6002 244.0001,-698.6001"/>
# </g>
# <!-- Cell 30: Extract Key -->
# <g id="node5" class="node">
# <title>Cell 30: Extract Key</title>
# <polygon fill="none" stroke="#0000ff" points="307.5,-616.1869 173.5,-616.1869 173.5,-580.1869 307.5,-580.1869 307.5,-616.1869"/>
# <text text-anchor="middle" x="240.5" y="-594.4869" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 30: Extract Key</text>
# </g>
# <!-- pcoll7082&#45;&gt;Cell 30: Extract Key -->
# <g id="edge4" class="edge">
# <title>pcoll7082&#45;&gt;Cell 30: Extract Key</title>
# <path fill="none" stroke="#000000" d="M240.5,-652.0182C240.5,-644.3178 240.5,-635.1612 240.5,-626.6035"/>
# <polygon fill="#000000" stroke="#000000" points="244.0001,-626.6001 240.5,-616.6001 237.0001,-626.6002 244.0001,-626.6001"/>
# </g>
# <!-- gold -->
# <g id="node6" class="node">
# <title>gold</title>
# <ellipse fill="none" stroke="#0000ff" cx="257.5" cy="-496.0911" rx="27.8951" ry="27.8951"/>
# <text text-anchor="middle" x="257.5" y="-492.3911" font-family="Times,serif" font-size="14.00" fill="#0000ff">gold</text>
# </g>
# <!-- Cell 30: Extract Key&#45;&gt;gold -->
# <g id="edge5" class="edge">
# <title>Cell 30: Extract Key&#45;&gt;gold</title>
# <path fill="none" stroke="#000000" d="M243.5393,-579.9342C245.6702,-567.1366 248.5952,-549.5702 251.2174,-533.8218"/>
# <polygon fill="#000000" stroke="#000000" points="254.6954,-534.2429 252.8855,-523.8038 247.7905,-533.0931 254.6954,-534.2429"/>
# </g>
# <!-- Cell 31: Join -->
# <g id="node15" class="node">
# <title>Cell 31: Join</title>
# <polygon fill="none" stroke="#0000ff" points="194.5,-411.9954 104.5,-411.9954 104.5,-375.9954 194.5,-375.9954 194.5,-411.9954"/>
# <text text-anchor="middle" x="149.5" y="-390.2954" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 31: Join</text>
# </g>
# <!-- gold&#45;&gt;Cell 31: Join -->
# <g id="edge6" class="edge">
# <title>gold&#45;&gt;Cell 31: Join</title>
# <path fill="none" stroke="#000000" d="M237.186,-476.8877C219.8933,-460.5403 194.9267,-436.9387 176.0533,-419.097"/>
# <polygon fill="#000000" stroke="#000000" points="178.3066,-416.4108 168.6353,-412.0845 173.4978,-421.4976 178.3066,-416.4108"/>
# </g>
# <!-- Cell 32: Join -->
# <g id="node29" class="node">
# <title>Cell 32: Join</title>
# <polygon fill="none" stroke="#0000ff" points="378.5,-411.9954 288.5,-411.9954 288.5,-375.9954 378.5,-375.9954 378.5,-411.9954"/>
# <text text-anchor="middle" x="333.5" y="-390.2954" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 32: Join</text>
# </g>
# <!-- gold&#45;&gt;Cell 32: Join -->
# <g id="edge7" class="edge">
# <title>gold&#45;&gt;Cell 32: Join</title>
# <path fill="none" stroke="#000000" d="M274.3669,-473.4328C286.0601,-457.7245 301.6679,-436.7575 313.9123,-420.3088"/>
# <polygon fill="#000000" stroke="#000000" points="316.8065,-422.2823 319.9702,-412.1708 311.1914,-418.1024 316.8065,-422.2823"/>
# </g>
# <!-- Cell 33: Join -->
# <g id="node43" class="node">
# <title>Cell 33: Join</title>
# <polygon fill="none" stroke="#0000ff" points="561.5,-411.9954 471.5,-411.9954 471.5,-375.9954 561.5,-375.9954 561.5,-411.9954"/>
# <text text-anchor="middle" x="516.5" y="-390.2954" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 33: Join</text>
# </g>
# <!-- gold&#45;&gt;Cell 33: Join -->
# <g id="edge8" class="edge">
# <title>gold&#45;&gt;Cell 33: Join</title>
# <path fill="none" stroke="#000000" d="M279.4272,-478.5669C292.9335,-468.4709 310.9686,-456.1965 328.5,-447.9954 371.2778,-427.9842 423.0603,-413.7786 461.4393,-404.9766"/>
# <polygon fill="#000000" stroke="#000000" points="462.3986,-408.3485 471.391,-402.7461 460.8676,-401.518 462.3986,-408.3485"/>
# </g>
# <!-- Cell 31: Read Preds -->
# <g id="node7" class="node">
# <title>Cell 31: Read Preds</title>
# <polygon fill="none" stroke="#0000ff" points="143,-1048.1869 12,-1048.1869 12,-1012.1869 143,-1012.1869 143,-1048.1869"/>
# <text text-anchor="middle" x="77.5" y="-1026.4869" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 31: Read Preds</text>
# </g>
# <!-- pcoll717 -->
# <g id="node8" class="node">
# <title>pcoll717</title>
# <ellipse fill="none" stroke="#0000ff" cx="77.5" cy="-958.1869" rx="18" ry="18"/>
# </g>
# <!-- Cell 31: Read Preds&#45;&gt;pcoll717 -->
# <g id="edge9" class="edge">
# <title>Cell 31: Read Preds&#45;&gt;pcoll717</title>
# <path fill="none" stroke="#000000" d="M77.5,-1012.0182C77.5,-1004.3178 77.5,-995.1612 77.5,-986.6035"/>
# <polygon fill="#000000" stroke="#000000" points="81.0001,-986.6001 77.5,-976.6001 74.0001,-986.6002 81.0001,-986.6001"/>
# </g>
# <!-- Cell 31: JSON loads -->
# <g id="node9" class="node">
# <title>Cell 31: JSON loads</title>
# <polygon fill="none" stroke="#0000ff" points="144.5,-904.1869 10.5,-904.1869 10.5,-868.1869 144.5,-868.1869 144.5,-904.1869"/>
# <text text-anchor="middle" x="77.5" y="-882.4869" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 31: JSON loads</text>
# </g>
# <!-- pcoll717&#45;&gt;Cell 31: JSON loads -->
# <g id="edge10" class="edge">
# <title>pcoll717&#45;&gt;Cell 31: JSON loads</title>
# <path fill="none" stroke="#000000" d="M77.5,-940.0182C77.5,-932.3178 77.5,-923.1612 77.5,-914.6035"/>
# <polygon fill="#000000" stroke="#000000" points="81.0001,-914.6001 77.5,-904.6001 74.0001,-914.6002 81.0001,-914.6001"/>
# </g>
# <!-- pcoll5989 -->
# <g id="node10" class="node">
# <title>pcoll5989</title>
# <ellipse fill="none" stroke="#0000ff" cx="77.5

# %%
pv1 = ib.ir.runners.interactive.display.pcoll_visualization.PCollectionVisualization(res1)
pdf1 = pv1._to_dataframe()
pv2 = ib.ir.runners.interactive.display.pcoll_visualization.PCollectionVisualization(res2)
pdf2 = pv2._to_dataframe()
pv3 = ib.ir.runners.interactive.display.pcoll_visualization.PCollectionVisualization(res3)
pdf3 = pv3._to_dataframe()
# Out:
# /usr/local/lib/python3.6/dist-packages/apache_beam/runners/interactive/display/pcoll_visualization.py:289: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   return json_normalize(normalized_list).applymap(

# %% [markdown]
# # Model Predictions vs Gold Labels

# %% [markdown]
# ## BiLSTM-C Baseline

# %%
pv1._display_dive(pdf1)
# Out:
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-dive sprite-image-width="64" sprite-image-height="64" id="facets_dive_res1_139945642490176_139945642488384_139945678155280" height="600"></facets-dive>
#             <script>
#               document.querySelector("#facets_dive_res1_139945642490176_139945642488384_139945678155280").data = [{"id":"0","source":"cardboard","negations":0,"form":"['In', 'choosing', 'a', 'few', 'typical', 'cases', 'which', 'illustrate', 'the', 'remarkable', 'mental', 'qualities', 'of', 'my', 'friend', ',', 'Sherlock', 'Holmes', ',', 'I', 'have', 'endeavoured', ',', 'as', 'far', 'as', 'possible', ',', 'to', 'select', 'those', 'which', 'presented', 'the', 'minimum', 'of', 'sensationalism', ',', 'while', 'offering', 'a', 'fair', 'field', 'for', 'his', 'talents', '.']","lemma":"['In', 'choose', 'a', 'few', 'typical', 'case', 'which', 'illustrate', 'the', 'remarkable', 'mental', 'quality', 'of', 'my', 'friend', ',', 'Sherlock', 'Holmes', ',', 'I', 'have', 'endeavour', ',', 'as', 'far', 'as', 'possible', ',', 'to', 'select', 'those', 'which', 'present', 'the', 'minimum', 'of', 'sensationalism', ',', 'while', 'offer', 'a', 'fair', 'field', 'for', 'his', 'talent', '.']","xpos":"['IN', 'VBG', 'DT', 'JJ', 'JJ', 'NNS', 'WDT', 'VBP', 'DT', 'JJ', 'JJ', 'NNS', 'IN', 'PRP$', 'NN', ',', 'NNP', 'NNP', ',', 'PRP', 'VBP', 'VBN', ',', 'RB', 'RB', 'IN', 'JJ', ',', 'TO', 'VB', 'DT', 'WDT', 'VBD', 'DT', 'NN', 'IN', 'NN', ',', 'IN', 'VBG', 'DT', 'JJ', 'NN', 'IN', 'PRP$', 'NNS', '.']","negation":"['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']","cue":"['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']","scope":"['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']","pred":"['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']","scopelen":0,"cuelen":0,"length":47,"acc":1.0,"precision":1.0,"recall":1.0,"mac_f1":1.0},{"id":"1","source":"cardboard","negations":2,"form":"['It', 'is', ',', 'however', ',', 'unfortunately', 'impossible', 'entirely', 'to', 'separate', 'the', 'sensational', 'from', 'the', 'criminal', ',', 'and', 'a', 'chronicler', 'is', 'left', 'in', 'the', 'dilemma', 'that', 'he', 'must', 'either', 'sacrifice', 'details', 'which', 'are', 'essential', 'to', 'his', 'statement', 'and', 'so', 'give', 'a', 'false', 'impression', 'of', 'the', 'problem', ',', 'or', 'he', 'must', 'use', 'matter', 'which', 'chance', ',', 'and', 'not', 'choice', ',', 'has', 'provided', 'him', 'with', '.']","lemma":"['It', 'be', ',', 'however', ',', 'unfortunately', 'impossible', 'entirely', 'to', 'separate', 'the', 'sensational', 'from', 'the', 'criminal', ',', 'and', 'a', 'chronicler', 'be', 'leave', 'in', 'the', 'dilemma', 'that', 'he', 'must', 'either', 'sacrifice', 'detail', 'which', 'be', 'essential', 'to', 'his', 'statement', 'and', 'so', 'give', 'a', 'false', 'impression', 'of', 'the', 'problem', ',', 'or', 'he', 'must', 'use', 'matter', 'which', 'chance', ',', 'and', 'not', 'choice', ',', 'have', 'provide', 'him', 'with', '.']","xpos":"['PRP', 'VBZ', ',', 'RB', ',', 'RB', 'JJ', 'RB', 'TO', 'VB', 'DT', 'JJ', 'IN', 'DT', 'JJ', ',', 'CC', 'DT', 'NN', 'VBZ', 'VBN', 'IN', 'DT', 'NN', 'IN', 'PRP', 'MD', 'RB', 'VB', 'NNS', 'WDT', 'VBP', 'JJ', 'TO', 'PRP$', 'NN', 'CC', 'RB', 'VB', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', ',', 'CC', 'PRP', 'MD', 'VB', 'NN', 'WDT', 'NN', ',', 'CC', 'RB', 'NN', ',', 'VBZ', 'VBN', 'PRP', 'IN', '.']","negation":"['F', 'F', 'T', 'T', 'T', 'T', 'A', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T ...

# %%
pv1._display_dataframe(pdf1)
# Out:
#             <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.2.2/jquery.min.js"></script>
#             <script src="https://cdn.datatables.net/1.10.20/js/jquery.dataTables.min.js"></script>
#             <link rel="stylesheet" href="https://cdn.datatables.net/1.10.20/css/jquery.dataTables.min.css">
#             <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe" id="table_df_res1_139945607557472_139945607558872_139945683942704">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>source</th>
#       <th>negations</th>
#       <th>form</th>
#       <th>lemma</th>
#       <th>xpos</th>
#       <th>negation</th>
#       <th>cue</th>
#       <th>scope</th>
#       <th>pred</th>
#       <th>scopelen</th>
#       <th>cuelen</th>
#       <th>length</th>
#       <th>acc</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>mac_f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['In', 'choosing', 'a', 'few', 'typical', 'cas...</td>
#       <td>['In', 'choose', 'a', 'few', 'typical', 'case'...</td>
#       <td>['IN', 'VBG', 'DT', 'JJ', 'JJ', 'NNS', 'WDT', ...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>47</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>cardboard</td>
#       <td>2</td>
#       <td>['It', 'is', ',', 'however', ',', 'unfortunate...</td>
#       <td>['It', 'be', ',', 'however', ',', 'unfortunate...</td>
#       <td>['PRP', 'VBZ', ',', 'RB', ',', 'RB', 'JJ', 'RB...</td>
#       <td>['F', 'F', 'T', 'T', 'T', 'T', 'A', 'F', 'F', ...</td>
#       <td>['', '', '', '', '', '', 'im', '', '', '', '',...</td>
#       <td>['It', 'is', '', '', '', '', 'possible', 'enti...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'F', 'A', 'F', 'F', ...</td>
#       <td>11</td>
#       <td>1</td>
#       <td>63</td>
#       <td>0.952381</td>
#       <td>0.712788</td>
#       <td>0.695192</td>
#       <td>0.703383</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>cardboard</td>
#       <td>2</td>
#       <td>['It', 'is', ',', 'however', ',', 'unfortunate...</td>
#       <td>['It', 'be', ',', 'however', ',', 'unfortunate...</td>
#       <td>['PRP', 'VBZ', ',', 'RB', ',', 'RB', 'JJ', 'RB...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>6</td>
#       <td>1</td>
#       <td>63</td>
#       <td>0.888889</td>
#       <td>0.562147</td>
#       <td>0.532738</td>
#       <td>0.540338</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['With', 'this', 'short', 'preface', 'I', 'sha...</td>
#       <td>['With', 'this', 'short', 'preface', 'I', 'sha...</td>
#       <td>['IN', 'DT', 'JJ', 'NN', 'PRP', 'MD', 'VB', 'T...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>27</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['It', 'was', 'a', 'blazing', 'hot', 'day', 'i...</td>
#       <td>['It', 'be', 'a', 'blazing', 'hot', 'day', 'in...</td>
#       <td>['PRP', 'VBD', 'DT', 'VBG', 'JJ', 'NN', 'IN', ...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']</td>
#       <td>['', '', '', '', '', '', '', '', '']</td>
#       <td>['', '', '', '', '', '', '', '', '']</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T']</td>
#       <td>0</td>
#       <td>0</td>
#       <td>9</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['Baker', 'Street', 'was', 'like', 'an', 'oven...</td>
#       <td>['Baker', 'Street', 'be', 'like', 'an', 'oven'...</td>
#       <td>['NNP', 'NNP', 'VBD', 'IN', 'DT', 'NN', ',', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>29</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>5</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['It', 'was', 'hard', 'to', 'believe', 'that',...</td>
#       <td>['It', 'be', 'hard', 'to', 'believe', 'that', ...</td>
#       <td>['PRP', 'VBD', 'JJ', 'TO', 'VB', 'IN', 'DT', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>21</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>6</td>
#       <td>cardboard</td>
#       <td>0</td>
#       <td>['Our', 'blinds', 'were', 'half-drawn', ',', '...</td>
#       <td>['Our', 'blind', 'be', 'half-drawn', ',', 'and...</td>
#       <td>['PRP$', 'NNS', 'VBD', 'JJ', ',', 'CC', 'NNP',...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>27</td>
#       <td>1.000000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>7</td>
#       <td>cardboard</td>
#       <td>1</td>
#       <td>['For', 'myself', ',', 'my', 'term', 'of', 'se...</td>
#       <td>['For', 'myself', ',', 'my', 'term', 'of', 'se...</td>
#       <td>['IN', 'PRP', ',', 'PRP$', 'NN', 'IN', 'NN', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['', '', '', '', '', '', '', '', '', '', '', '...</td>
#       <td>['T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', 'T', ...</td>
#       <td>6</td>
#       <td>1</td>
#       <td>28</td>
#       <td>0.892857</td>
#       <td>0.718750</td>
#       <td>0.625000</td>
#       <td>0.650000</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>8</td>
#       <td>cardboard</td>
#       <td>1</td>
#       <td>['But', 'the', 'morning', 'paper', 'was', 'uni...</td>
#       <td>['But', 'the', 'morning', 'paper', 'be', 'unin...</td>
#       <td>['CC', 'DT', 'NN', 'NN', 'VBD', 'JJ', '.']</td>
#       <td>['T', 'F', 'F', 'F', 'F', 'A', 'T']</td>
#       <td>['', '', '', '', '', 'un', '']</td>
#       <td>['', 'the', 'morning', 'paper', 'was', 'intere...</td>
#       <td>['T', 'F', 'F', 'F', 'F', 'A', 'T']</td>
#       <td>5</td>
#       <td>1</td>
#       <td>7</td>
#       <td>1.000000</td>
#       <td>0.750000</td>
#       <td>0.750000</td>
#       <td>0.750000</td>

# %% [markdown]
# ## BiLSTM-C Baseline - Larger hidden dimension

# %%
pv2._display_dive(pdf2)

# %% [markdown]
# ## BiLSTM-CE - BERT embeddings

# %%
pv = ib.ir.runners.interactive.display.pcoll_visualization.PCollectionVisualization(res)
pdf1 = pv._to_dataframe()
pv._display_dive(pdf1)

# %%
p = beam.Pipeline(interactive_runner.InteractiveRunner())

fpattern = "Saves/*/*/eval_pred_corr_tidy.epe"

preds = (
    p
    | "Read Preds" >> beam.io.ReadFromTextWithFilename(fpattern)
    | "Map JSON" >> beam.Map(
        lambda x: dict({"model": "-".join(x[0].split("/")[1:3])}, **json.loads(x[1]))
        )
    | "Create Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
    | "Get Preds Only" >> beam.Map(
        lambda x: (x[0], {x[1]["model"]: x[1]["negation"]})
        )
    | "Join Preds" >> beam.GroupByKey()
    | "Merge Preds" >> beam.Map(
        lambda x: (x[0], dict(ChainMap(*x[1])))
        )
)

gold = (
    p 
    | "Read Gold" >> beam.io.ReadFromText("DataFiles/cde.epe")
    | "Convert to Dict" >> beam.Map(json.loads)
    | "Extract Key" >> beam.Map(
        lambda x: (x["id"]+x["source"]+"X".join(x["cue"]), x)
        )
)

res_full = (
    {"gold": gold, "preds": preds} 
    | "Join" >> beam.CoGroupByKey()
    | "Clean" >> beam.Map(
        lambda x: dict(x[1]["gold"][0], **x[1]["preds"][0])
        )
)

# %%
ib.show(res)

# %%
result = p.run()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="337pt" height="1155pt"
#  viewBox="0.00 0.00 336.50 1154.69" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1150.6909)">
# <title>G</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-1150.6909 332.5,-1150.6909 332.5,4 -4,4"/>
# <!-- Cell 102: Read Preds -->
# <g id="node1" class="node">
# <title>Cell 102: Read Preds</title>
# <polygon fill="none" stroke="#0000ff" points="150,-1146.6909 12,-1146.6909 12,-1110.6909 150,-1110.6909 150,-1146.6909"/>
# <text text-anchor="middle" x="81" y="-1124.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Read Preds</text>
# </g>
# <!-- pcoll2913 -->
# <g id="node2" class="node">
# <title>pcoll2913</title>
# <ellipse fill="none" stroke="#0000ff" cx="81" cy="-1056.6909" rx="18" ry="18"/>
# </g>
# <!-- Cell 102: Read Preds&#45;&gt;pcoll2913 -->
# <g id="edge1" class="edge">
# <title>Cell 102: Read Preds&#45;&gt;pcoll2913</title>
# <path fill="none" stroke="#000000" d="M81,-1110.5222C81,-1102.8218 81,-1093.6652 81,-1085.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-1085.1041 81,-1075.1042 77.5001,-1085.1042 84.5001,-1085.1041"/>
# </g>
# <!-- Cell 102: Map JSON -->
# <g id="node3" class="node">
# <title>Cell 102: Map JSON</title>
# <polygon fill="none" stroke="#0000ff" points="150,-1002.6909 12,-1002.6909 12,-966.6909 150,-966.6909 150,-1002.6909"/>
# <text text-anchor="middle" x="81" y="-980.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Map JSON</text>
# </g>
# <!-- pcoll2913&#45;&gt;Cell 102: Map JSON -->
# <g id="edge2" class="edge">
# <title>pcoll2913&#45;&gt;Cell 102: Map JSON</title>
# <path fill="none" stroke="#000000" d="M81,-1038.5222C81,-1030.8218 81,-1021.6652 81,-1013.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-1013.1041 81,-1003.1042 77.5001,-1013.1042 84.5001,-1013.1041"/>
# </g>
# <!-- pcoll5251 -->
# <g id="node4" class="node">
# <title>pcoll5251</title>
# <ellipse fill="none" stroke="#0000ff" cx="81" cy="-912.6909" rx="18" ry="18"/>
# </g>
# <!-- Cell 102: Map JSON&#45;&gt;pcoll5251 -->
# <g id="edge3" class="edge">
# <title>Cell 102: Map JSON&#45;&gt;pcoll5251</title>
# <path fill="none" stroke="#000000" d="M81,-966.5222C81,-958.8218 81,-949.6652 81,-941.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-941.1041 81,-931.1042 77.5001,-941.1042 84.5001,-941.1041"/>
# </g>
# <!-- Cell 102: Create Key -->
# <g id="node5" class="node">
# <title>Cell 102: Create Key</title>
# <polygon fill="none" stroke="#0000ff" points="149.5,-858.6909 12.5,-858.6909 12.5,-822.6909 149.5,-822.6909 149.5,-858.6909"/>
# <text text-anchor="middle" x="81" y="-836.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Create Key</text>
# </g>
# <!-- pcoll5251&#45;&gt;Cell 102: Create Key -->
# <g id="edge4" class="edge">
# <title>pcoll5251&#45;&gt;Cell 102: Create Key</title>
# <path fill="none" stroke="#000000" d="M81,-894.5222C81,-886.8218 81,-877.6652 81,-869.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-869.1041 81,-859.1042 77.5001,-869.1042 84.5001,-869.1041"/>
# </g>
# <!-- pcoll4333 -->
# <g id="node6" class="node">
# <title>pcoll4333</title>
# <ellipse fill="none" stroke="#0000ff" cx="81" cy="-768.6909" rx="18" ry="18"/>
# </g>
# <!-- Cell 102: Create Key&#45;&gt;pcoll4333 -->
# <g id="edge5" class="edge">
# <title>Cell 102: Create Key&#45;&gt;pcoll4333</title>
# <path fill="none" stroke="#000000" d="M81,-822.5222C81,-814.8218 81,-805.6652 81,-797.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-797.1041 81,-787.1042 77.5001,-797.1042 84.5001,-797.1041"/>
# </g>
# <!-- Cell 102: Get Preds Only -->
# <g id="node7" class="node">
# <title>Cell 102: Get Preds Only</title>
# <polygon fill="none" stroke="#0000ff" points="162,-714.6909 0,-714.6909 0,-678.6909 162,-678.6909 162,-714.6909"/>
# <text text-anchor="middle" x="81" y="-692.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Get Preds Only</text>
# </g>
# <!-- pcoll4333&#45;&gt;Cell 102: Get Preds Only -->
# <g id="edge6" class="edge">
# <title>pcoll4333&#45;&gt;Cell 102: Get Preds Only</title>
# <path fill="none" stroke="#000000" d="M81,-750.5222C81,-742.8218 81,-733.6652 81,-725.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-725.1041 81,-715.1042 77.5001,-725.1042 84.5001,-725.1041"/>
# </g>
# <!-- pcoll4377 -->
# <g id="node8" class="node">
# <title>pcoll4377</title>
# <ellipse fill="none" stroke="#0000ff" cx="81" cy="-624.6909" rx="18" ry="18"/>
# </g>
# <!-- Cell 102: Get Preds Only&#45;&gt;pcoll4377 -->
# <g id="edge7" class="edge">
# <title>Cell 102: Get Preds Only&#45;&gt;pcoll4377</title>
# <path fill="none" stroke="#000000" d="M81,-678.5222C81,-670.8218 81,-661.6652 81,-653.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-653.1041 81,-643.1042 77.5001,-653.1042 84.5001,-653.1041"/>
# </g>
# <!-- Cell 102: Join Preds -->
# <g id="node9" class="node">
# <title>Cell 102: Join Preds</title>
# <polygon fill="none" stroke="#0000ff" points="147.5,-570.6909 14.5,-570.6909 14.5,-534.6909 147.5,-534.6909 147.5,-570.6909"/>
# <text text-anchor="middle" x="81" y="-548.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Join Preds</text>
# </g>
# <!-- pcoll4377&#45;&gt;Cell 102: Join Preds -->
# <g id="edge8" class="edge">
# <title>pcoll4377&#45;&gt;Cell 102: Join Preds</title>
# <path fill="none" stroke="#000000" d="M81,-606.5222C81,-598.8218 81,-589.6652 81,-581.1075"/>
# <polygon fill="#000000" stroke="#000000" points="84.5001,-581.1041 81,-571.1042 77.5001,-581.1042 84.5001,-581.1041"/>
# </g>
# <!-- pcoll2185 -->
# <g id="node10" class="node">
# <title>pcoll2185</title>
# <ellipse fill="none" stroke="#0000ff" cx="83" cy="-480.6909" rx="18" ry="18"/>
# </g>
# <!-- Cell 102: Join Preds&#45;&gt;pcoll2185 -->
# <g id="edge9" class="edge">
# <title>Cell 102: Join Preds&#45;&gt;pcoll2185</title>
# <path fill="none" stroke="#000000" d="M81.5047,-534.5222C81.7186,-526.8218 81.9729,-517.6652 82.2106,-509.1075"/>
# <polygon fill="#000000" stroke="#000000" points="85.7094,-509.1975 82.4885,-499.1042 78.7121,-509.0031 85.7094,-509.1975"/>
# </g>
# <!-- Cell 102: Merge Preds -->
# <g id="node11" class="node">
# <title>Cell 102: Merge Preds</title>
# <polygon fill="none" stroke="#0000ff" points="157,-426.6909 11,-426.6909 11,-390.6909 157,-390.6909 157,-426.6909"/>
# <text text-anchor="middle" x="84" y="-404.9909" font-family="Times,serif" font-size="14.00" fill="#0000ff">Cell 102: Merge Preds</text>
# </g>
# <!-- pcoll2185&#45;&gt;Cell 102: Merge Preds -->
# <g id="edge10" class="edge">
# <title>pcoll2185&#45;&gt;Cell 102: Merge Preds</title>
# <path fill="none" stroke="#000000" d="M83.2523,-462.5222C83.3593,-454.8218 83.4865,-445.6652 83.6053,-437.1075"/>
# <polygon fill="#000000" stroke="#000000" points="87.1049,-437.1518 83.7443,-427.1042 80.1056,-437.0545 87.1049,-437.1518"/>
# </g>
# <!-- preds -->
# <g id="node12" class="node">
# <title>preds</title>
# <ellipse fill="none" stroke="#0000ff" cx="127" cy="-324.1436" rx="30.5947" ry="30.5947"/>
# <text text-anchor="middle" x="127" y="-320.4436" font-family="Times,serif" font-size="14.00" fill="#0000ff">preds</text>
# </g>
# <!-- Cell 102: Merge Preds&#45;&gt;preds -->
# <g id="edge11" class="edge">
# <title>Cell 102: Merge Preds&#45;&gt;preds</title>
# <path fill="none" stroke="#000000" d="M93.3304,-390.3454C97.7556,-381.6444 103.2065,-370.9269 108.4233,-360.6694"/>
# <polygon fill="#000000" stroke="#000000" points="111.6988,-361.9497 113.1124,-351.4496 105.4594,-358.7763 111.6988,-361.9497"/>
# </g>
# <!-- Cell 102: Join -->
# <g id="node19" class="node">
# <title>Cell 102: Join</title>
# <polygon fill="none" stroke="#0000ff" points="214,-257.5963 116,-257.5963 116,-221.5963 214,-221.5963 214,-257.5963"/>
# <text text-anchor="middle" x="165" y="-235.8963" font-fami

# %%
with open("negation/cde.epe") as f:
  S = [json.loads(line) for line in f]

# %%
def filter(S, id, source):
  for i in S:
    if i["id"] == id:
      if i["source"] == source:
        for n in i.get("nodes"):
          print(n.get("form"))
          for nn in n.get("negation"):
            print("\t", nn, end="\t")
          print("")

# %%
filter(S, "50", "circle01")
# Out:
# He
# 	 {'id': 148}
# has
# 	 {'id': 148}
# been
# 	 {'id': 148}
# there
# 	 {'id': 148}
# for
# 	 {'id': 148}
# ten
# 	 {'id': 148}
# days
# 	 {'id': 148}
# ,
# 	 {'id': 148}
# and
# 	 {'id': 148}
# neither
# 	 {'id': 148, 'cue': 'neither'}
# Mr.
# 	 {'id': 148, 'scope': 'Mr.'}
# Warren
# 	 {'id': 148, 'scope': 'Warren'}
# ,
# 	 {'id': 148, 'scope': ','}
# nor
# 	 {'id': 148, 'cue': 'nor'}
# I
# 	 {'id': 148, 'scope': 'I'}
# ,
# 	 {'id': 148, 'scope': ','}
# nor
# 	 {'id': 148, 'cue': 'nor'}
# the
# 	 {'id': 148, 'scope': 'the'}
# girl
# 	 {'id': 148, 'scope': 'girl'}
# has
# 	 {'id': 148, 'scope': 'has'}
# once
# 	 {'id': 148, 'scope': 'once'}
# set
# 	 {'id': 148, 'scope': 'set', 'event': 'set'}
# eyes
# 	 {'id': 148, 'scope': 'eyes', 'event': 'eyes'}
# upon
# 	 {'id': 148, 'scope': 'upon'}
# him
# 	 {'id': 148, 'scope': 'him'}
# .
# 	 {'id': 148}

# %%
[1, 2, 3] == [2, 1, 3]
# Out:
# False

# %%
len('')
# Out:
# 0
